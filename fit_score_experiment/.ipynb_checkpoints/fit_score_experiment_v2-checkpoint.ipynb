# %% [markdown]
# #### Develop the formula for Fit-score
# It must have following properties:
# * larger value of the score indicates better groupings of users (users of similarities are grouped togehter)
# * it promotes formation of a fewer set of user groups/communities
#
# #### A promoted version of Fit-Score
# $$
# fs_1 = \sum_{j = 1}^{k} \frac{|U_{j}|^2}{N} (\sum_{i \in U_{j}} \text{P-value}(u_i,D_j)_{i}) - C \cdot |\text{buffer}|
# $$
#
#
# * $u_i$: $i$th user
# * $D_j$: the distance metrics learned for $j$th user group
# * $U_j$: $j$th user group
# * $|\cdot|$: size of users in the container
# * $C$: the parameter determines the strength of penalty for more members in the buffer
# * $N$: the total number of users in fit group, $\sum_{j = 1}^{k} |U_{j}|$

# %%
from git_fit_score import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Experiment Objective:
#     * Factos Subjective to Test:
#         a. the number of groups
#         b. the size of populations
#         c. goodness of fit of members to group
#     * simulation data
#         a. p-value score of each members to given group
#         b. composition of groups

# %% [markdown]
# #### Experiment 01:   2-group population

# %%
# user defined function to generate simulation values

def drawGroup(true_group, error_prob, all_group_labels):
    """ Draw random group label from a complete set of all_group_label """
    import numpy as np
    
    is_error = np.random.sample() < error_prob
    
    if isinstance(all_group_labels, tuple):
        all_group_labels = all_group_labels[:]
    
    if is_error:
        other_group_labels = [label for label in all_group_labels if label != true_group]
        actual_label = np.random.choice(other_group_labels, 1)[0]
    else:
        actual_label = true_group
    
    return actual_label 


def genPval(true_group, actual_group, true_min_pval=0.8):
    """ Generate p-value based on the true_group and actual_group """
    import numpy as np
    
    is_diff = not true_group == actual_group
    if is_diff:
        pval = np.random.uniform(0, true_min_pval)
    else:
        pval = np.random.uniform(true_min_pval, 1)
    return pval


def genSimData(pop_size, group_prob, mis_classification_prob):
    """Generate simulation output form the learning algorithm"""
    
    if not sum(group_prob)==1:
        try:
            raise ValueError('HiThere')
        except ValueError:
            print("ERROR: group probabilities do not sum to 1!")

    true_num_group = len(group_prob)
    uniq_group_labels = range(true_num_group)

    # generate user basic information
    user_ids = range(pop_size)
    # , size=None, replace=True, p=None
    true_groups = np.random.choice(uniq_group_labels, size=pop_size, replace=True, p=group_prob)

    sim_result = pd.DataFrame({"user_id": user_ids, "true_group": true_groups})

    # generate conditioanl results
    sim_result["actual_group"] = [drawGroup(tg, mis_classification_prob, uniq_group_labels) \
                                  for tg in sim_result.true_group]
    sim_result["pval"] = sim_result[["true_group", "actual_group"]].apply(lambda x: genPval(x[0], x[1], 0.8), \
                                                                          axis=1)
    return sim_result


def simDataTransform(sim_data, buffer_size=0):
    """ re-structure simulated data.frame into tuple (pvalue-list, buffer-list)
    """
    pval_group = []
    for group_id in sim_data.actual_group.unique():
        pvalues = list(sim_data.ix[sim_data.actual_group == group_id, "pval"])
        pval_group.append(pvalues)

    # generate buffer, remove selected user from sim_data
    # and put them in buffers (user_id)
    buffers = []
    # method is not implemented 
    
    return (pval_group, buffers)


def statSummary(x):
    """Return a descriptive summary to describe the distribution """
    x_mean = np.mean(x)
    x_median = np.median(x)
    x_std = np.std(x)
    x_min, x_max = min(x), max(x)
    return (x_mean, x_median, x_std, x_min, x_max)


def expExectuor(param_grid, k_fold=100):
    """ Conduct simulation experiment based on given
        experiment configuraiton.
    """

    import time
    
    # input argument
    param_meshgrid_df = pd.DataFrame(list(param_grid))

    # calcualte job information
    total_iteration = param_meshgrid_df.shape[0]

    # output dataframe container
    exp_results = param_meshgrid_df.copy()
    # statistics container
    fs_mean, fs_median, fs_std, fs_min, fs_max = [], [], [], [], []
    exp_time_costs = []

    for i, param_row in param_meshgrid_df.iterrows():
        # load experiment parameter
        the_pop_size = param_row["pop_size"]
        the_group_prob = param_row["group_prob"]
        the_misclass_prob = param_row["misclass_prob"]

        print("{0}th (out of {1}) experiment is under conducting...".format(i, total_iteration))

        fit_scores = []
        start_time = time.time()
        for i_rep in range(k_fold):

            sim_result = genSimData(the_pop_size, the_group_prob, the_misclass_prob )
            transformed = simDataTransform(sim_result)
            the_fit_score = get_fit_score(transformed[0], transformed[1], c=1)
            fit_scores.append(the_fit_score)

        duration_time = (time.time() - start_time)
        print("Time cost: {0:.1f} seconds".format(duration_time))

        fs_mean.append(np.mean(fit_scores))
        fs_median.append(np.median(fit_scores))
        fs_std.append(np.std(fit_scores))
        fs_min.append(max(fit_scores))
        fs_max.append(min(fit_scores))

        exp_time_costs.append(duration_time)

    exp_results["pval_mean"] = fs_mean
    exp_results["pval_median"] = fs_median
    exp_results["pval_std"] = fs_std
    exp_results["pval_min"] = fs_min
    exp_results["pval_max"] = fs_max
    exp_results["time_cost"] = exp_time_costs
    return exp_results

# %%
import numpy as np
import pandas as pd

# set random seed
np.random.seed(123)

# generate user_id, true_group, label_group, p_val
pop_size = 100
group_prob = (0.5, 0.5)
error_prob = 0.1

# %%
#  simluation pipeline showcase
sim_result = genSimData(pop_size=100, group_prob=[0.5, 0.3, 0.2], mis_classification_prob=0.1)
transformed = simDataTransform(sim_result)
fit_score = get_fit_score(transformed[0], transformed[1], c=1)
print("fit score: {0:.2f}".format(fit_score))
# Out:
# fit score: 1435.39

# %%
# validate the generated data
match_idx = sim_result[["true_group", "actual_group"]].apply(lambda x: x[0]==x[1], axis=1)
dismatch_idx = [not i for i in match_idx]

sim_result.ix[match_idx, "pval"].hist(range=[0, 1], facecolor="green")
sim_result.ix[dismatch_idx, "pval"].hist(range=[0, 1], facecolor="red")
plt.show()

sim_result.actual_group.value_counts().plot(kind='pie')
plt.axis('equal')
plt.title('Number of Members per Actual Group')

# %%
# define the parameter meshgrid
from sklearn.grid_search import ParameterGrid

pop_size_range = [10**i for i in range(2, 7)]
group_prob_range = [(a, 1-a) for a in np.arange(0.5, 0.95, 0.05)]                
misclass_prob_range = list(np.arange(0.0, 0.50, 0.05))

param_ranges = {"pop_size": pop_size_range, "group_prob": group_prob_range, 
                "misclass_prob": misclass_prob_range}

param_meshgrid = ParameterGrid(param_ranges)

# %%
exp_results = expExectuor(param_meshgrid, k_fold=10)
# Out:
# 0th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 1th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 2th (out of 450) experiment is under conducting...
# Time cost: 4.2 seconds
# 3th (out of 450) experiment is under conducting...
# Time cost: 42.0 seconds
# 4th (out of 450) experiment is under conducting...
# Time cost: 417.9 seconds
# 5th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 6th (out of 450) experiment is under conducting...
# Time cost: 0.6 seconds
# 7th (out of 450) experiment is under conducting...
# Time cost: 4.6 seconds
# 8th (out of 450) experiment is under conducting...
# Time cost: 42.4 seconds
# 9th (out of 450) experiment is under conducting...
# Time cost: 413.0 seconds
# 10th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 11th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 12th (out of 450) experiment is under conducting...
# Time cost: 4.1 seconds
# 13th (out of 450) experiment is under conducting...
# Time cost: 41.3 seconds
# 14th (out of 450) experiment is under conducting...
# Time cost: 413.4 seconds
# 15th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 16th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 17th (out of 450) experiment is under conducting...
# Time cost: 4.2 seconds
# 18th (out of 450) experiment is under conducting...
# Time cost: 42.0 seconds
# 19th (out of 450) experiment is under conducting...
# Time cost: 420.3 seconds
# 20th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 21th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 22th (out of 450) experiment is under conducting...
# Time cost: 4.3 seconds
# 23th (out of 450) experiment is under conducting...
# Time cost: 42.5 seconds
# 24th (out of 450) experiment is under conducting...
# Time cost: 423.1 seconds
# 25th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 26th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 27th (out of 450) experiment is under conducting...
# Time cost: 4.3 seconds
# 28th (out of 450) experiment is under conducting...
# Time cost: 42.6 seconds
# 29th (out of 450) experiment is under conducting...
# Time cost: 428.6 seconds
# 30th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 31th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 32th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 33th (out of 450) experiment is under conducting...
# Time cost: 43.3 seconds
# 34th (out of 450) experiment is under conducting...
# Time cost: 430.6 seconds
# 35th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 36th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 37th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 38th (out of 450) experiment is under conducting...
# Time cost: 43.4 seconds
# 39th (out of 450) experiment is under conducting...
# Time cost: 434.4 seconds
# 40th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 41th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 42th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 43th (out of 450) experiment is under conducting...
# Time cost: 43.9 seconds
# 44th (out of 450) experiment is under conducting...
# Time cost: 439.1 seconds
# 45th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 46th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 47th (out of 450) experiment is under conducting...
# Time cost: 4.5 seconds
# 48th (out of 450) experiment is under conducting...
# Time cost: 44.7 seconds
# 49th (out of 450) experiment is under conducting...
# Time cost: 445.3 seconds
# 50th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 51th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 52th (out of 450) experiment is under conducting...
# Time cost: 4.1 seconds
# 53th (out of 450) experiment is under conducting...
# Time cost: 40.5 seconds
# 54th (out of 450) experiment is under conducting...
# Time cost: 407.0 seconds
# 55th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 56th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 57th (out of 450) experiment is under conducting...
# Time cost: 4.1 seconds
# 58th (out of 450) experiment is under conducting...
# Time cost: 41.2 seconds
# 59th (out of 450) experiment is under conducting...
# Time cost: 411.8 seconds
# 60th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 61th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 62th (out of 450) experiment is under conducting...
# Time cost: 4.2 seconds
# 63th (out of 450) experiment is under conducting...
# Time cost: 41.6 seconds
# 64th (out of 450) experiment is under conducting...
# Time cost: 415.6 seconds
# 65th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 66th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 67th (out of 450) experiment is under conducting...
# Time cost: 4.2 seconds
# 68th (out of 450) experiment is under conducting...
# Time cost: 42.0 seconds
# 69th (out of 450) experiment is under conducting...
# Time cost: 419.0 seconds
# 70th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 71th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 72th (out of 450) experiment is under conducting...
# Time cost: 4.2 seconds
# 73th (out of 450) experiment is under conducting...
# Time cost: 42.3 seconds
# 74th (out of 450) experiment is under conducting...
# Time cost: 423.9 seconds
# 75th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 76th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 77th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 78th (out of 450) experiment is under conducting...
# Time cost: 42.9 seconds
# 79th (out of 450) experiment is under conducting...
# Time cost: 428.3 seconds
# 80th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 81th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 82th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 83th (out of 450) experiment is under conducting...
# Time cost: 43.1 seconds
# 84th (out of 450) experiment is under conducting...
# Time cost: 434.0 seconds
# 85th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 86th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 87th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 88th (out of 450) experiment is under conducting...
# Time cost: 43.7 seconds
# 89th (out of 450) experiment is under conducting...
# Time cost: 438.3 seconds
# 90th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 91th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 92th (out of 450) experiment is under conducting...
# Time cost: 4.5 seconds
# 93th (out of 450) experiment is under conducting...
# Time cost: 44.2 seconds
# 94th (out of 450) experiment is under conducting...
# Time cost: 443.0 seconds
# 95th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 96th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 97th (out of 450) experiment is under conducting...
# Time cost: 4.5 seconds
# 98th (out of 450) experiment is under conducting...
# Time cost: 44.5 seconds
# 99th (out of 450) experiment is under conducting...
# Time cost: 443.2 seconds
# 100th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 101th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 102th (out of 450) experiment is under conducting...
# Time cost: 4.1 seconds
# 103th (out of 450) experiment is under conducting...
# Time cost: 40.4 seconds
# 104th (out of 450) experiment is under conducting...
# Time cost: 405.3 seconds
# 105th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 106th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 107th (out of 450) experiment is under conducting...
# Time cost: 4.1 seconds
# 108th (out of 450) experiment is under conducting...
# Time cost: 41.6 seconds
# 109th (out of 450) experiment is under conducting...
# Time cost: 411.2 seconds
# 110th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 111th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 112th (out of 450) experiment is under conducting...
# Time cost: 4.1 seconds
# 113th (out of 450) experiment is under conducting...
# Time cost: 41.4 seconds
# 114th (out of 450) experiment is under conducting...
# Time cost: 412.3 seconds
# 115th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 116th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 117th (out of 450) experiment is under conducting...
# Time cost: 4.2 seconds
# 118th (out of 450) experiment is under conducting...
# Time cost: 41.7 seconds
# 119th (out of 450) experiment is under conducting...
# Time cost: 416.5 seconds
# 120th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 121th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 122th (out of 450) experiment is under conducting...
# Time cost: 4.2 seconds
# 123th (out of 450) experiment is under conducting...
# Time cost: 42.3 seconds
# 124th (out of 450) experiment is under conducting...
# Time cost: 425.1 seconds
# 125th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 126th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 127th (out of 450) experiment is under conducting...
# Time cost: 4.3 seconds
# 128th (out of 450) experiment is under conducting...
# Time cost: 43.0 seconds
# 129th (out of 450) experiment is under conducting...
# Time cost: 426.5 seconds
# 130th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 131th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 132th (out of 450) experiment is under conducting...
# Time cost: 4.3 seconds
# 133th (out of 450) experiment is under conducting...
# Time cost: 44.7 seconds
# 134th (out of 450) experiment is under conducting...
# Time cost: 435.6 seconds
# 135th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 136th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 137th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 138th (out of 450) experiment is under conducting...
# Time cost: 44.4 seconds
# 139th (out of 450) experiment is under conducting...
# Time cost: 435.6 seconds
# 140th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 141th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 142th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 143th (out of 450) experiment is under conducting...
# Time cost: 43.8 seconds
# 144th (out of 450) experiment is under conducting...
# Time cost: 440.9 seconds
# 145th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 146th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 147th (out of 450) experiment is under conducting...
# Time cost: 4.5 seconds
# 148th (out of 450) experiment is under conducting...
# Time cost: 44.6 seconds
# 149th (out of 450) experiment is under conducting...
# Time cost: 445.0 seconds
# 150th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 151th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 152th (out of 450) experiment is under conducting...
# Time cost: 4.1 seconds
# 153th (out of 450) experiment is under conducting...
# Time cost: 40.7 seconds
# 154th (out of 450) experiment is under conducting...
# Time cost: 406.2 seconds
# 155th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 156th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 157th (out of 450) experiment is under conducting...
# Time cost: 4.1 seconds
# 158th (out of 450) experiment is under conducting...
# Time cost: 41.0 seconds
# 159th (out of 450) experiment is under conducting...
# Time cost: 410.8 seconds
# 160th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 161th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 162th (out of 450) experiment is under conducting...
# Time cost: 4.2 seconds
# 163th (out of 450) experiment is under conducting...
# Time cost: 41.6 seconds
# 164th (out of 450) experiment is under conducting...
# Time cost: 413.5 seconds
# 165th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 166th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 167th (out of 450) experiment is under conducting...
# Time cost: 4.2 seconds
# 168th (out of 450) experiment is under conducting...
# Time cost: 41.7 seconds
# 169th (out of 450) experiment is under conducting...
# Time cost: 418.7 seconds
# 170th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 171th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 172th (out of 450) experiment is under conducting...
# Time cost: 4.3 seconds
# 173th (out of 450) experiment is under conducting...
# Time cost: 42.4 seconds
# 174th (out of 450) experiment is under conducting...
# Time cost: 423.0 seconds
# 175th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 176th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 177th (out of 450) experiment is under conducting...
# Time cost: 4.3 seconds
# 178th (out of 450) experiment is under conducting...
# Time cost: 42.9 seconds
# 179th (out of 450) experiment is under conducting...
# Time cost: 426.7 seconds
# 180th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 181th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 182th (out of 450) experiment is under conducting...
# Time cost: 4.3 seconds
# 183th (out of 450) experiment is under conducting...
# Time cost: 43.2 seconds
# 184th (out of 450) experiment is under conducting...
# Time cost: 431.3 seconds
# 185th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 186th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 187th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 188th (out of 450) experiment is under conducting...
# Time cost: 43.5 seconds
# 189th (out of 450) experiment is under conducting...
# Time cost: 435.4 seconds
# 190th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 191th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 192th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 193th (out of 450) experiment is under conducting...
# Time cost: 44.1 seconds
# 194th (out of 450) experiment is under conducting...
# Time cost: 441.0 seconds
# 195th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 196th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 197th (out of 450) experiment is under conducting...
# Time cost: 4.5 seconds
# 198th (out of 450) experiment is under conducting...
# Time cost: 44.4 seconds
# 199th (out of 450) experiment is under conducting...
# Time cost: 445.3 seconds
# 200th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 201th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 202th (out of 450) experiment is under conducting...
# Time cost: 4.1 seconds
# 203th (out of 450) experiment is under conducting...
# Time cost: 40.7 seconds
# 204th (out of 450) experiment is under conducting...
# Time cost: 407.3 seconds
# 205th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 206th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 207th (out of 450) experiment is under conducting...
# Time cost: 4.1 seconds
# 208th (out of 450) experiment is under conducting...
# Time cost: 41.2 seconds
# 209th (out of 450) experiment is under conducting...
# Time cost: 411.7 seconds
# 210th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 211th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 212th (out of 450) experiment is under conducting...
# Time cost: 4.1 seconds
# 213th (out of 450) experiment is under conducting...
# Time cost: 41.5 seconds
# 214th (out of 450) experiment is under conducting...
# Time cost: 416.1 seconds
# 215th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 216th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 217th (out of 450) experiment is under conducting...
# Time cost: 4.2 seconds
# 218th (out of 450) experiment is under conducting...
# Time cost: 41.6 seconds
# 219th (out of 450) experiment is under conducting...
# Time cost: 417.3 seconds
# 220th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 221th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 222th (out of 450) experiment is under conducting...
# Time cost: 4.3 seconds
# 223th (out of 450) experiment is under conducting...
# Time cost: 42.5 seconds
# 224th (out of 450) experiment is under conducting...
# Time cost: 425.2 seconds
# 225th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 226th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 227th (out of 450) experiment is under conducting...
# Time cost: 4.3 seconds
# 228th (out of 450) experiment is under conducting...
# Time cost: 43.1 seconds
# 229th (out of 450) experiment is under conducting...
# Time cost: 430.7 seconds
# 230th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 231th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 232th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 233th (out of 450) experiment is under conducting...
# Time cost: 43.6 seconds
# 234th (out of 450) experiment is under conducting...
# Time cost: 434.8 seconds
# 235th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 236th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 237th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 238th (out of 450) experiment is under conducting...
# Time cost: 43.7 seconds
# 239th (out of 450) experiment is under conducting...
# Time cost: 436.9 seconds
# 240th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 241th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 242th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 243th (out of 450) experiment is under conducting...
# Time cost: 44.5 seconds
# 244th (out of 450) experiment is under conducting...
# Time cost: 441.0 seconds
# 245th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 246th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 247th (out of 450) experiment is under conducting...
# Time cost: 4.5 seconds
# 248th (out of 450) experiment is under conducting...
# Time cost: 44.8 seconds
# 249th (out of 450) experiment is under conducting...
# Time cost: 445.3 seconds
# 250th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 251th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 252th (out of 450) experiment is under conducting...
# Time cost: 4.0 seconds
# 253th (out of 450) experiment is under conducting...
# Time cost: 40.6 seconds
# 254th (out of 450) experiment is under conducting...
# Time cost: 404.3 seconds
# 255th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 256th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 257th (out of 450) experiment is under conducting...
# Time cost: 4.1 seconds
# 258th (out of 450) experiment is under conducting...
# Time cost: 41.5 seconds
# 259th (out of 450) experiment is under conducting...
# Time cost: 411.3 seconds
# 260th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 261th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 262th (out of 450) experiment is under conducting...
# Time cost: 4.2 seconds
# 263th (out of 450) experiment is under conducting...
# Time cost: 42.0 seconds
# 264th (out of 450) experiment is under conducting...
# Time cost: 414.7 seconds
# 265th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 266th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 267th (out of 450) experiment is under conducting...
# Time cost: 4.2 seconds
# 268th (out of 450) experiment is under conducting...
# Time cost: 42.1 seconds
# 269th (out of 450) experiment is under conducting...
# Time cost: 420.0 seconds
# 270th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 271th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 272th (out of 450) experiment is under conducting...
# Time cost: 4.3 seconds
# 273th (out of 450) experiment is under conducting...
# Time cost: 42.6 seconds
# 274th (out of 450) experiment is under conducting...
# Time cost: 424.9 seconds
# 275th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 276th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 277th (out of 450) experiment is under conducting...
# Time cost: 4.3 seconds
# 278th (out of 450) experiment is under conducting...
# Time cost: 43.0 seconds
# 279th (out of 450) experiment is under conducting...
# Time cost: 429.0 seconds
# 280th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 281th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 282th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 283th (out of 450) experiment is under conducting...
# Time cost: 43.1 seconds
# 284th (out of 450) experiment is under conducting...
# Time cost: 434.8 seconds
# 285th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 286th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 287th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 288th (out of 450) experiment is under conducting...
# Time cost: 43.5 seconds
# 289th (out of 450) experiment is under conducting...
# Time cost: 436.0 seconds
# 290th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 291th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 292th (out of 450) experiment is under conducting...
# Time cost: 4.5 seconds
# 293th (out of 450) experiment is under conducting...
# Time cost: 44.3 seconds
# 294th (out of 450) experiment is under conducting...
# Time cost: 441.3 seconds
# 295th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 296th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 297th (out of 450) experiment is under conducting...
# Time cost: 4.5 seconds
# 298th (out of 450) experiment is under conducting...
# Time cost: 44.9 seconds
# 299th (out of 450) experiment is under conducting...
# Time cost: 445.7 seconds
# 300th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 301th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 302th (out of 450) experiment is under conducting...
# Time cost: 4.1 seconds
# 303th (out of 450) experiment is under conducting...
# Time cost: 41.1 seconds
# 304th (out of 450) experiment is under conducting...
# Time cost: 408.6 seconds
# 305th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 306th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 307th (out of 450) experiment is under conducting...
# Time cost: 4.1 seconds
# 308th (out of 450) experiment is under conducting...
# Time cost: 41.3 seconds
# 309th (out of 450) experiment is under conducting...
# Time cost: 411.5 seconds
# 310th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 311th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 312th (out of 450) experiment is under conducting...
# Time cost: 4.2 seconds
# 313th (out of 450) experiment is under conducting...
# Time cost: 41.6 seconds
# 314th (out of 450) experiment is under conducting...
# Time cost: 416.3 seconds
# 315th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 316th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 317th (out of 450) experiment is under conducting...
# Time cost: 4.2 seconds
# 318th (out of 450) experiment is under conducting...
# Time cost: 42.0 seconds
# 319th (out of 450) experiment is under conducting...
# Time cost: 420.2 seconds
# 320th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 321th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 322th (out of 450) experiment is under conducting...
# Time cost: 4.2 seconds
# 323th (out of 450) experiment is under conducting...
# Time cost: 42.3 seconds
# 324th (out of 450) experiment is under conducting...
# Time cost: 423.9 seconds
# 325th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 326th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 327th (out of 450) experiment is under conducting...
# Time cost: 4.3 seconds
# 328th (out of 450) experiment is under conducting...
# Time cost: 42.7 seconds
# 329th (out of 450) experiment is under conducting...
# Time cost: 428.7 seconds
# 330th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 331th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 332th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 333th (out of 450) experiment is under conducting...
# Time cost: 43.6 seconds
# 334th (out of 450) experiment is under conducting...
# Time cost: 434.4 seconds
# 335th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 336th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 337th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 338th (out of 450) experiment is under conducting...
# Time cost: 44.1 seconds
# 339th (out of 450) experiment is under conducting...
# Time cost: 439.4 seconds
# 340th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 341th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 342th (out of 450) experiment is under conducting...
# Time cost: 4.5 seconds
# 343th (out of 450) experiment is under conducting...
# Time cost: 44.7 seconds
# 344th (out of 450) experiment is under conducting...
# Time cost: 440.8 seconds
# 345th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 346th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 347th (out of 450) experiment is under conducting...
# Time cost: 4.5 seconds
# 348th (out of 450) experiment is under conducting...
# Time cost: 44.5 seconds
# 349th (out of 450) experiment is under conducting...
# Time cost: 442.7 seconds
# 350th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 351th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 352th (out of 450) experiment is under conducting...
# Time cost: 4.1 seconds
# 353th (out of 450) experiment is under conducting...
# Time cost: 40.5 seconds
# 354th (out of 450) experiment is under conducting...
# Time cost: 404.5 seconds
# 355th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 356th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 357th (out of 450) experiment is under conducting...
# Time cost: 4.2 seconds
# 358th (out of 450) experiment is under conducting...
# Time cost: 41.2 seconds
# 359th (out of 450) experiment is under conducting...
# Time cost: 410.7 seconds
# 360th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 361th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 362th (out of 450) experiment is under conducting...
# Time cost: 4.2 seconds
# 363th (out of 450) experiment is under conducting...
# Time cost: 41.3 seconds
# 364th (out of 450) experiment is under conducting...
# Time cost: 415.8 seconds
# 365th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 366th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 367th (out of 450) experiment is under conducting...
# Time cost: 4.2 seconds
# 368th (out of 450) experiment is under conducting...
# Time cost: 41.9 seconds
# 369th (out of 450) experiment is under conducting...
# Time cost: 420.0 seconds
# 370th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 371th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 372th (out of 450) experiment is under conducting...
# Time cost: 4.3 seconds
# 373th (out of 450) experiment is under conducting...
# Time cost: 42.7 seconds
# 374th (out of 450) experiment is under conducting...
# Time cost: 423.0 seconds
# 375th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 376th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 377th (out of 450) experiment is under conducting...
# Time cost: 4.3 seconds
# 378th (out of 450) experiment is under conducting...
# Time cost: 42.7 seconds
# 379th (out of 450) experiment is under conducting...
# Time cost: 425.5 seconds
# 380th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 381th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 382th (out of 450) experiment is under conducting...
# Time cost: 4.3 seconds
# 383th (out of 450) experiment is under conducting...
# Time cost: 43.0 seconds
# 384th (out of 450) experiment is under conducting...
# Time cost: 431.6 seconds
# 385th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 386th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 387th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 388th (out of 450) experiment is under conducting...
# Time cost: 43.7 seconds
# 389th (out of 450) experiment is under conducting...
# Time cost: 436.4 seconds
# 390th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 391th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 392th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 393th (out of 450) experiment is under conducting...
# Time cost: 44.4 seconds
# 394th (out of 450) experiment is under conducting...
# Time cost: 441.1 seconds
# 395th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 396th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 397th (out of 450) experiment is under conducting...
# Time cost: 4.5 seconds
# 398th (out of 450) experiment is under conducting...
# Time cost: 44.9 seconds
# 399th (out of 450) experiment is under conducting...
# Time cost: 448.0 seconds
# 400th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 401th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 402th (out of 450) experiment is under conducting...
# Time cost: 4.1 seconds
# 403th (out of 450) experiment is under conducting...
# Time cost: 40.9 seconds
# 404th (out of 450) experiment is under conducting...
# Time cost: 407.5 seconds
# 405th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 406th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 407th (out of 450) experiment is under conducting...
# Time cost: 4.1 seconds
# 408th (out of 450) experiment is under conducting...
# Time cost: 41.3 seconds
# 409th (out of 450) experiment is under conducting...
# Time cost: 410.6 seconds
# 410th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 411th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 412th (out of 450) experiment is under conducting...
# Time cost: 4.2 seconds
# 413th (out of 450) experiment is under conducting...
# Time cost: 41.6 seconds
# 414th (out of 450) experiment is under conducting...
# Time cost: 417.9 seconds
# 415th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 416th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 417th (out of 450) experiment is under conducting...
# Time cost: 4.3 seconds
# 418th (out of 450) experiment is under conducting...
# Time cost: 42.5 seconds
# 419th (out of 450) experiment is under conducting...
# Time cost: 421.5 seconds
# 420th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 421th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 422th (out of 450) experiment is under conducting...
# Time cost: 4.3 seconds
# 423th (out of 450) experiment is under conducting...
# Time cost: 43.1 seconds
# 424th (out of 450) experiment is under conducting...
# Time cost: 425.8 seconds
# 425th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 426th (out of 450) experiment is under conducting...
# Time cost: 0.4 seconds
# 427th (out of 450) experiment is under conducting...
# Time cost: 4.3 seconds
# 428th (out of 450) experiment is under conducting...
# Time cost: 42.9 seconds
# 429th (out of 450) experiment is under conducting...
# Time cost: 429.2 seconds
# 430th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 431th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 432th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 433th (out of 450) experiment is under conducting...
# Time cost: 43.6 seconds
# 434th (out of 450) experiment is under conducting...
# Time cost: 434.3 seconds
# 435th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 436th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 437th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 438th (out of 450) experiment is under conducting...
# Time cost: 43.6 seconds
# 439th (out of 450) experiment is under conducting...
# Time cost: 437.2 seconds
# 440th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 441th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 442th (out of 450) experiment is under conducting...
# Time cost: 4.4 seconds
# 443th (out of 450) experiment is under conducting...
# Time cost: 44.3 seconds
# 444th (out of 450) experiment is under conducting...
# Time cost: 444.3 seconds
# 445th (out of 450) experiment is under conducting...
# Time cost: 0.1 seconds
# 446th (out of 450) experiment is under conducting...
# Time cost: 0.5 seconds
# 447th (out of 450) experiment is under conducting...
# Time cost: 4.5 seconds
# 448th (out of 450) experiment is under conducting...
# Time cost: 44.5 seconds
# 449th (out of 450) experiment is under conducting...
# Time cost: 446.2 seconds

# %%
import datetime
dt = datetime.datetime.now().strftime('%Y%m%d_%H%M')
fname = "result_%s.csv" % dt
exp_results.to_csv(fname, sep=",", header=True, index=False)

# %%
exp_results["pop_size"].unique()
# Out:
# array([    100,    1000,   10000,  100000, 1000000])

# %%
data_plot.head(10)
# Out:
#    group_prob  misclass_prob  pop_size     pval_mean   pval_median  \
# 0  (0.5, 0.5)           0.00       100  2.351389e+03  2.296519e+03
# 1  (0.5, 0.5)           0.00       100  2.257828e+05  2.251845e+05
# 2  (0.5, 0.5)           0.00       100  2.250441e+07  2.250276e+07
# 3  (0.5, 0.5)           0.00       100  2.250146e+09  2.250155e+09
# 4  (0.5, 0.5)           0.00       100  2.250021e+11  2.249977e+11
# 5  (0.5, 0.5)           0.05       100  2.233864e+03  2.237314e+03
# 6  (0.5, 0.5)           0.05       100  2.195603e+05  2.188599e+05
# 7  (0.5, 0.5)           0.05       100  2.189319e+07  2.188799e+07
# 8  (0.5, 0.5)           0.05       100  2.187120e+09  2.186968e+09
# 9  (0.5, 0.5)           0.05       100  2.187443e+11  2.187468e+11
#
#           pval_std      pval_min      pval_max   time_cost  log_pval_mean
# 0       128.459449  2.588482e+03  2.226951e+03    0.060066       3.371325
# 1      1466.512914  2.293173e+05  2.245043e+05    0.426315       5.353691
# 2     13970.254108  2.253406e+07  2.248563e+07    4.207481       7.352268
# 3    336854.492455  2.250622e+09  2.249460e+09   42.014748       9.352211
# 4  12198750.710634  2.250322e+11  2.249874e+11  417.868880      11.352187
# 5        81.588932  2.425479e+03  2.134554e+03    0.070016       3.349057
# 6      2320.220341  2.263918e+05  2.179667e+05    0.596575       5.341554
# 7     27888.901051  2.197111e+07  2.186667e+07    4.559647       7.340309
# 8    781255.671193  2.188903e+09  2.186071e+09   42.425209       9.339873
# 9  30201807.479930  2.187951e+11  2.187050e+11  413.020480      11.339937

# %%
exp_results["log_pval_mean"] = [np.math.log(pval_mean, 10) for pval_mean in list(exp_results["pval_mean"])]
exp_results["group_a_prob"] = [a for a, b in exp_results["group_prob"]]

# %%
from ggplot import *

ggplot(exp_results, aes(x="misclass_prob", y="log_pval_mean", group="pop_size", colour="pop_size")) + \
    geom_line() + \
    geom_errorbar("pval_std", position="dodge", width=0.2) + \
    xlab("Mis-Classification Probability") + ylab("Log(P-value's mean)") + \
    theme_bw()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-aa41b693d805> in <module>()
#       1 from ggplot import *
#       2
# ----> 3 ggplot(exp_results, aes(x="misclass_prob", y="log_pval_mean", group="pop_size", colour="pop_size")) +     geom_line() +     geom_errorbar("pval_std", position="dodge", width=0.2) +     xlab("Mis-Classification Probability") + ylab("Log(P-value's mean)") +     theme_bw()
#
# NameError: name 'geom_errorbar' is not defined

# %%
data_plot = exp_results[exp_results["pop_size"]==100]

# %%
plt.scatter(data_plot["misclass_prob"], data_plot["pval_mean"], c=data_plot["group_a_prob"])
plt.gray()
plt.legend()
plt.show()
# Out:
# /home/beingzy/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:475: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
data_plot["pop_size"]
# Out:
# Series([], Name: misclass_prob, dtype: float64)

# %%
exp_results["group_a_prob"].unique()
# Out:
# array([ 0.5 ,  0.55,  0.6 ,  0.65,  0.7 ,  0.75,  0.8 ,  0.85,  0.9 ])

# %%
import seaborn as sns

sns.set_style("darkgrid")
ax = sns.pointplot(x="misclass_prob", y="pval_mean", data=data_plot)

# %%
data_plot = exp_results[exp_results["pop_size"]==100]
# data_plot = data_plot[data_plot["group_a_prob"] < 0.8]

sns.lmplot("misclass_prob", "pval_mean", data=data_plot, hue="group_a_prob", fit_reg=False, \
            scatter_kws={'alpha':0.8}, size=8, aspect=1.5)

# %%
plt.hist(data_plot.pval_mean)
# Out:
# (array([ 360.,    0.,   26.,   35.,   12.,    8.,    3.,    3.,    2.,    1.]),
#  array([  1.70143136e+03,   6.56944239e+10,   1.31388846e+11,
#           1.97083268e+11,   2.62777690e+11,   3.28472113e+11,
#           3.94166535e+11,   4.59860957e+11,   5.25555379e+11,
#           5.91249801e+11,   6.56944224e+11]),
#  <a list of 10 Patch objects>)

# %%
data_plot[data_plot["pval_mean"] < 1]
# Out:
# Empty DataFrame
# Columns: [group_prob, misclass_prob, pop_size, pval_mean, pval_median, pval_std, pval_min, pval_max, time_cost, log_pval_mean, group_a_prob]
# Index: []

# %%
sum()
