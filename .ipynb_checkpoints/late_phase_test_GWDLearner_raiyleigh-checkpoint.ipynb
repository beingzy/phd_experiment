# %%
import os
import sys
import glob
import numpy as np
import scipy as sp
import pandas as pd
import networkx as nx
from matplotlib import pyplot as plt

from scipy.stats import rayleigh
from scipy.stats import ks_2samp
from numpy import linspace
from numpy.random import choice
from networkx import Graph

from learning_dist_metrics.ldm import LDM
from learning_dist_metrics.dist_metrics import weighted_euclidean

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
DATA_PATH = "./data/sim_data_yi/" 

users_df   = pd.read_csv(DATA_PATH + "users_profile.csv", header = 0, sep = ",")
friends_df = pd.read_csv(DATA_PATH + "friendships.csv", header = 0, sep = ",")
dist_df    = pd.read_csv(DATA_PATH + "dist_mat.csv", header = 0, sep = ",")

friends_df = friends_df[friends_df.isFriend == 1]
friends_df["pair"] = friends_df[["uid_a", "uid_b"]].apply(lambda x: (int(x[0]), int(x[1])), axis=1)
friends_df.drop("isFriend", axis=1, inplace=True)
friends_df = friends_df[["pair", "uid_a", "uid_b"]]
friends_df.head(3)

cols = ["x0", "x1", "x2", "x3", "x4", "x5"]

## subset users data to retain profile only
profile_df = users_df[["ID"] + cols]
all_user_ids = list(set(users_df.ID))

# %%
from GWDLearner import *

profile_df = profile_df      # user profile
friends_ls = friends_df.pair # user relationship

# %%
import cProfile, pstats, StringIO

pr = cProfile.Profile()
pr.enable()
print "Profiler start analyzing ... "

res = learning_wrapper(profile_df=profile_df, friends_pair=friends_ls, max_iter=5,\
                       k=2, c=0.1, dropout_rate=0.2, fit_rayleigh=True, verbose=True)

pr.disable()
print "Profiler stop here ... "
# Out:
# Profiler start analyzing ...
# Initiating ...
# 1 iteration is in processing ...
# --- 34.55 seconds ---
# --- 26.84 seconds ---
# 1) #fit: 62, #unfit: 38, #buffer: 0
# 1) #fit: 62, #unfit: 38, #buffer: 0
# 1) #fit: 67, #unfit: 0, #buffer: 33
# 2 iteration is in processing ...
# --- 53.77 seconds ---
# --- 38.46 seconds ---
# 1) #fit: 55, #unfit: 12, #buffer: 33
# 1) #fit: 77, #unfit: 12, #buffer: 11
# 1) #fit: 81, #unfit: 0, #buffer: 19
# 3 iteration is in processing ...
# --- 37.69 seconds ---
# --- 111.39 seconds ---
# 1) #fit: 52, #unfit: 29, #buffer: 19
# 1) #fit: 60, #unfit: 29, #buffer: 11
# 1) #fit: 66, #unfit: 0, #buffer: 34
# ** dropout is activating ...
#
# 4 iteration is in processing ...
# --- 64.80 seconds ---
# --- 42.51 seconds ---
# 1) #fit: 56, #unfit: 10, #buffer: 34
# 1) #fit: 79, #unfit: 10, #buffer: 11
# 1) #fit: 80, #unfit: 0, #buffer: 20
# 5 iteration is in processing ...
# --- 39.67 seconds ---
# --- 68.17 seconds ---
# 1) #fit: 55, #unfit: 25, #buffer: 20
# 1) #fit: 64, #unfit: 25, #buffer: 11
# 1) #fit: 68, #unfit: 0, #buffer: 32
# ** dropout is activating ...
#
# 6 iteration is in processing ...
# --- 46.67 seconds ---
# --- 62.93 seconds ---
# 1) #fit: 57, #unfit: 11, #buffer: 32
# 1) #fit: 78, #unfit: 11, #buffer: 11
# 1) #fit: 82, #unfit: 0, #buffer: 18
# ** dropout is activating ...
#
# 7 iteration is in processing ...
# --- 36.53 seconds ---
# --- 39.96 seconds ---
# 1) #fit: 56, #unfit: 26, #buffer: 18
# 1) #fit: 63, #unfit: 26, #buffer: 11
# 1) #fit: 70, #unfit: 0, #buffer: 30
# ** dropout is activating ...
#
# 8 iteration is in processing ...
# --- 53.84 seconds ---
# --- 47.74 seconds ---
# 1) #fit: 55, #unfit: 15, #buffer: 30
# 1) #fit: 74, #unfit: 15, #buffer: 11
# 1) #fit: 78, #unfit: 0, #buffer: 22
# ** dropout is activating ...
#
# 9 iteration is in processing ...
# --- 43.80 seconds ---
# --- 36.61 seconds ---
# 1) #fit: 57, #unfit: 21, #buffer: 22
# 1) #fit: 68, #unfit: 21, #buffer: 11
# 1) #fit: 68, #unfit: 0, #buffer: 32
# ** dropout is activating ...
#
# Profiler stop here ...

# %%
s = StringIO.StringIO()
sortby = 'cumulative'
ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
ps.print_stats()
print s.getvalue()
# Out:
#          1226927261 function calls (1189028819 primitive calls) in 1031.140 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.000    0.000 1031.140  343.713 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:3005(run_code)
#         1    0.000    0.000 1031.140 1031.140 <ipython-input-4-83f818a3e67e>:7(<module>)
#         1    0.014    0.014 1031.140 1031.140 GWDLearner.py:452(learning_wrapper)
#        18    0.245    0.014  913.252   50.736 GWDLearner.py:262(ldm_train_with_list)
#        18    0.004    0.000  913.007   50.723 learning_dist_metrics/ldm.py:48(fit)
#        18    0.071    0.004  913.002   50.722 learning_dist_metrics/ldm.py:88(_fit)
#    131576    0.157    0.000  891.123    0.007 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.py:280(function_wrapper)
#      3364    0.026    0.000  890.629    0.265 learning_dist_metrics/ldm.py:143(objective_func)
#      6728   12.856    0.002  890.283    0.132 learning_dist_metrics/dist_metrics.py:62(all_pairwise_dist)
#        18    0.000    0.000  885.952   49.220 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/optimize/_minimize.py:37(minimize)
#        18    0.014    0.001  885.951   49.219 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/optimize/lbfgsb.py:199(_minimize_lbfgsb)
#       478    0.002    0.000  885.935    1.853 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/optimize/lbfgsb.py:260(func_and_grad)
#  17588576   38.257    0.000  875.659    0.000 learning_dist_metrics/dist_metrics.py:29(pairwise_dist_wrapper)
#      3364    0.056    0.000  770.631    0.229 learning_dist_metrics/dist_metrics.py:88(sum_grouped_dist)
#       478    0.028    0.000  759.135    1.588 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.py:544(_approx_fprime_helper)
#  17696189  207.501    0.000  637.258    0.000 learning_dist_metrics/dist_metrics.py:13(weighted_euclidean)
#  17696189   30.310    0.000  360.476    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/spatial/distance.py:199(euclidean)
#  17697276   21.440    0.000  208.352    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:2199(as_matrix)
#  35392378   39.362    0.000  189.576    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/spatial/distance.py:119(_validate_vector)
#  17696189   39.166    0.000  140.591    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/linalg/misc.py:12(norm)
#      3364    0.138    0.000  119.972    0.036 learning_dist_metrics/dist_metrics.py:110(squared_sum_grouped_dist)
#  17697276   20.446    0.000  116.498    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2701(as_matrix)
#      1087    1.768    0.002  104.165    0.096 GWDLearner.py:34(user_grouped_dist)
#  17696189   28.911    0.000   94.145    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.py:550(asarray_chkfinite)
#  17697294   39.765    0.000   86.256    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2246(_is_single_block)
#  54848253   21.876    0.000   83.472    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/numeric.py:394(asarray)
#  35395037   40.420    0.000   79.868    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/shape_base.py:8(atleast_1d)
# 90927023/90818323   78.792    0.000   79.542    0.000 {numpy.core.multiarray.array}
#  17805976   19.578    0.000   71.017    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:2130(_consolidate_inplace)
#    108700    0.501    0.000   70.378    0.001 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:62(__getitem__)
#    108700    0.808    0.000   69.647    0.001 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:689(_getitem_tuple)
#  35394137   67.373    0.000   67.373    0.000 {zip}
#    217400    0.780    0.000   61.423    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:892(_getitem_axis)
#    217400    1.243    0.000   56.785    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:922(_getitem_iterable)
#  17943667    6.663    0.000   52.806    0.000 {method 'all' of 'numpy.ndarray' objects}
# 258234336/220665513   29.161    0.000   48.559    0.000 {len}
#  17943667    5.678    0.000   46.143    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:40(_all)
#  19109381   43.398    0.000   43.398    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       395    0.005    0.000   40.672    0.103 GWDLearner.py:313(find_fit_group)
#  17805976   14.561    0.000   35.947    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:2122(_protect_consolidate)
#  35523129   14.149    0.000   31.411    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/numeric.py:464(asanyarray)
#  17588594   10.126    0.000   27.222    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2369(__len__)
#    217418    0.966    0.000   24.896    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:3124(reindex_indexer)
#    108718    0.668    0.000   23.722    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:1339(take)
#    108700    1.068    0.000   20.192    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/ops.py:574(wrapper)
#    108718    0.789    0.000   20.007    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:3255(take)
#    108700    0.202    0.000   19.762    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/frame.py:2507(reindex_axis)
#    108700    0.476    0.000   19.560    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:1838(reindex_axis)
#  17805976    7.977    0.000   19.240    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:2131(<lambda>)
#        18   17.162    0.953   17.798    0.989 learning_dist_metrics/ldm.py:224(get_exclusive_pairs)
#  18023397   15.702    0.000   15.702    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:2085(__setattr__)
#      1087    0.011    0.000   13.677    0.013 GWDLearner.py:113(user_dist_kstest)
#    108700    0.660    0.000   12.341    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:1851(_reindex_with_indexers)
#  17805976    7.081    0.000   11.263    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2821(consolidate)
#    217418    0.942    0.000   10.668    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2163(__init__)
#    108700    0.348    0.000    9.994    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2674(copy)
#    217401    1.364    0.000    8.643    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/series.py:118(__init__)
#  38496322    7.009    0.000    8.251    0.000 {isinstance}
#  19980229    6.193    0.000    7.912    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:243(__len__)
#    217418    0.778    0.000    7.855    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:845(take_nd)
#    217401    0.100    0.000    7.733    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:212(isnull)
#    217401    0.396    0.000    7.633    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:233(_isnull_new)
#      1758    0.023    0.000    7.564    0.004 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:1977(fit)
#    108700    0.798    0.000    7.336    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2396(apply)
#      1758    0.012    0.000    7.252    0.004 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.py:287(fmin)
#      1758    1.246    0.001    7.240    0.004 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.py:387(_minimize_neldermead)
# 23132520/22915120    6.305    0.000    7.211    0.000 {getattr}
#    217418    1.907    0.000    7.201    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:110(__new__)
#    217418    2.987    0.000    6.912    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2258(_rebuild_blknos_and_blklocs)
#  18893031    5.394    0.000    6.786    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2208(ndim)
#    217400    1.739    0.000    6.703    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:303(_isnull_ndarraylike)
#      1087    0.009    0.000    5.836    0.005 GWDLearner.py:90(kstest_2samp_greater)
#      1087    0.009    0.000    5.782    0.005 /home/beingzy/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:171(__call__)
#      1087    5.488    0.005    5.772    0.005 /home/beingzy/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:101(__call__)
#    217454    1.652    0.000    5.749    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:756(take_nd)
#  53536224    5.681    0.000    5.681    0.000 {method 'append' of 'list' objects}
#    108700    0.374    0.000    5.674    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:1868(reindex)
#    978336    1.518    0.000    5.352    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:2121(is_bool_indexer)
#  37133807    5.279    0.000    5.279    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:119(mgr_locs)
#    652200    0.604    0.000    5.172    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:1156(_has_valid_type)
#    128230    2.115    0.000    5.071    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:1902(_penalized_nnlf)
#    108700    0.174    0.000    4.784    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:4230(logical_func)
#    108700    0.328    0.000    4.611    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/series.py:2061(_reduce)
#  35392378    4.524    0.000    4.524    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#  18023394    4.441    0.000    4.441    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:874(get_values)
#    189416    2.138    0.000    4.428    0.000 learning_dist_metrics/ldm.py:269(find_index)
#  18240812    4.309    0.000    4.309    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2560(is_consolidated)
#    108700    1.212    0.000    4.232    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2715(_interleave)
#    869655    0.450    0.000    4.036    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:5672(_ensure_index)
#    108700    0.140    0.000    3.816    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/nanops.py:236(nanany)
#   1386313    2.462    0.000    3.757    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:2569(is_categorical_dtype)
#    869690    1.631    0.000    3.491    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2204(shape)
#    217400    0.862    0.000    3.361    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/series.py:2589(_sanitize_array)
#    652219    1.210    0.000    3.306    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2073(make_block)
#    108700    0.432    0.000    3.153    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/nanops.py:156(_get_values)
#  17697314    3.105    0.000    3.105    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2279(_get_items)
#    326118    0.696    0.000    3.101    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:344(_shallow_copy)
#    326136    1.685    0.000    3.007    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:2347(_asarray_tuplesafe)
#  19882986    2.905    0.000    2.905    0.000 {method 'get' of 'dict' objects}
#    762766    0.388    0.000    2.838    0.000 {method 'any' of 'numpy.ndarray' objects}
#   1304472    0.782    0.000    2.616    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:318(_get_axis)
#   1984723    0.862    0.000    2.535    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/series.py:286(dtype)
#    762766    0.298    0.000    2.450    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:37(_any)
#    217401    0.564    0.000    2.434    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:3343(__init__)
#    108700    0.266    0.000    2.347    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:123(_has_valid_tuple)
#    190541    0.539    0.000    2.314    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/series.py:1001(__iter__)
#    217400    0.116    0.000    2.310    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2694(<lambda>)
#    217400    0.203    0.000    2.194    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:332(view)
#    543536    0.994    0.000    2.108    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:205(_simple_new)
#    108700    0.550    0.000    2.103    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:790(_getitem_lowerdim)
#    108718    0.266    0.000    1.991    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:1139(take)
#    652219    1.117    0.000    1.968    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:64(__init__)
#   2609070    0.584    0.000    1.860    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2206(<genexpr>)
#    108700    0.704    0.000    1.857    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:715(_multi_take_opportunity)
#    978318    0.552    0.000    1.769    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:1735(is_list_like_indexer)
#    434800    0.534    0.000    1.759    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:132(_should_validate_iterable)
#    217436    0.797    0.000    1.741    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:1105(_maybe_promote)
#    108700    0.178    0.000    1.682    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:1639(check_bool_indexer)
#   1984723    0.694    0.000    1.673    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:3453(dtype)
#   1413172    1.190    0.000    1.648    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:305(_get_axis_name)
#    217418    0.793    0.000    1.612    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/frame.py:199(__init__)
#    108718    0.830    0.000    1.563    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:1686(maybe_convert_indices)
#    217400    0.401    0.000    1.520    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:504(copy)
#    108718    0.210    0.000    1.495    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:1224(equals)
#    217400    0.251    0.000    1.444    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/series.py:2604(_try_cast)
#   3020436    1.197    0.000    1.403    0.000 {hasattr}
#    128230    0.121    0.000    1.375    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:1875(_nnlf)
#    327188    0.578    0.000    1.371    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:2068(__getattr__)
#    108718    0.395    0.000    1.349    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2384(_verify_integrity)
#    108700    0.943    0.000    1.286    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:3744(_interleaved_dtype)
#    217418    0.569    0.000    1.266    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:407(array_equivalent)
#   1739237    0.676    0.000    1.242    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:70(_check)
#    217400    0.261    0.000    1.234    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:3434(equals)
#   2392664    0.824    0.000    1.233    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:3394(_values)
#    217419    0.260    0.000    1.147    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:128(make_block_same_class)
#    217418    0.555    0.000    1.105    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2568(_consolidate_check)
#   1195772    0.735    0.000    1.102    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:2461(_get_dtype_type)
#    217419    1.085    0.000    1.085    0.000 {pandas.lib.infer_dtype}
#    978318    0.563    0.000    1.065    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:2603(is_list_like)
#    108700    0.594    0.000    1.052    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/ops.py:543(na_op)
#    108701    0.582    0.000    1.022    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:731(is_unique)
#    760974    0.478    0.000    1.020    0.000 {pandas.lib.values_from_object}
#    890978    0.969    0.000    0.969    0.000 {numpy.core.multiarray.empty}
#   5445366    0.964    0.000    0.964    0.000 {issubclass}
#    217400    0.508    0.000    0.918    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:2440(is_datetimelike)
#    108700    0.651    0.000    0.913    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:1974(_possibly_cast_to_datetime)
#    128230    0.309    0.000    0.868    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:1527(_logpdf)
#    407941    0.222    0.000    0.861    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/series.py:306(values)
#    256532    0.225    0.000    0.855    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:1631(sum)
#    326118    0.786    0.000    0.838    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:328(_get_attributes_dict)
#    217400    0.113    0.000    0.793    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/series.py:317(get_values)
#    108700    0.793    0.000    0.793    0.000 {pandas.algos.take_2d_axis1_int64_int64}
#    326118    0.278    0.000    0.723    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:1046(_indexer)
#    543536    0.343    0.000    0.712    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/compat/__init__.py:123(iteritems)
#    434819    0.697    0.000    0.697    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:90(__init__)
#    217400    0.316    0.000    0.681    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:3481(get_values)
#    326118    0.219    0.000    0.663    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:2557(is_bool_dtype)
#    217400    0.139    0.000    0.651    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:1739(is_label_like)
#    407941    0.257    0.000    0.639    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:3477(values)
#      8951    0.637    0.000    0.637    0.000 {method 'remove' of 'list' objects}
#    217400    0.219    0.000    0.614    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:2443(_coerce_to_dtype)
#    762061    0.374    0.000    0.597    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:264(values)
#    652201    0.311    0.000    0.577    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:386(ndim)
#    128230    0.379    0.000    0.564    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/lib/ufunclike.py:116(isneginf)
#    128230    0.559    0.000    0.559    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:3539(_pdf)
#    108700    0.552    0.000    0.552    0.000 {pandas.algos.take_2d_axis1_float64_float64}
#    434836    0.210    0.000    0.542    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:269(get_values)
#    217418    0.203    0.000    0.541    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:322(_get_block_manager_axis)
#    256532    0.073    0.000    0.534    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:31(_sum)
#    326118    0.436    0.000    0.530    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:292(_get_axis_number)
#    108700    0.077    0.000    0.525    0.000 {all}
#    652219    0.427    0.000    0.523    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:141(mgr_locs)
#    434818    0.418    0.000    0.516    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:232(ftype)
#    217401    0.379    0.000    0.516    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/series.py:255(_set_axis)
#    109824    0.191    0.000    0.503    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/frame.py:1768(__getitem__)
#   1496120    0.474    0.000    0.474    0.000 {method 'view' of 'numpy.ndarray' objects}
#    326100    0.098    0.000    0.447    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:722(<genexpr>)
#    108700    0.272    0.000    0.447    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:142(_is_nested_tuple_indexer)
#   2610064    0.446    0.000    0.446    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:3390(_block)
#    108700    0.059    0.000    0.443    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/series.py:389(__array__)
#    217418    0.146    0.000    0.432    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:2495(is_integer_dtype)
#    434818    0.428    0.000    0.428    0.000 {numpy.core.multiarray.arange}
#    381082    0.215    0.000    0.415    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/numerictypes.py:736(issubdtype)
#    108718    0.091    0.000    0.404    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:905(_convert_list_indexer)
#    115464    0.199    0.000    0.402    0.000 {sum}
#    108700    0.055    0.000    0.365    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/nanops.py:213(_view_if_needed)
#    108700    0.092    0.000    0.365    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:107(_validate_dtype)
#    217454    0.253    0.000    0.351    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:724(_get_take_nd_function)
#    434836    0.203    0.000    0.330    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2836(_consolidate_inplace)
#    217418    0.250    0.000    0.318    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:120(_init_mgr)
#    329616    0.316    0.000    0.316    0.000 {method 'copy' of 'numpy.ndarray' objects}
#    108700    0.079    0.000    0.310    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:2526(is_datetime_or_timedelta_dtype)
#    108700    0.064    0.000    0.288    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/nanops.py:209(_na_ok_dtype)
#    544052    0.286    0.000    0.286    0.000 {method 'iteritems' of 'dict' objects}
#      1758    0.004    0.000    0.271    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:1931(_fitstart)
#    108701    0.147    0.000    0.271    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:949(_engine)
#    434800    0.238    0.000    0.269    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:746(is_floating)
#      1758    0.015    0.000    0.267    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:2061(fit_loc_scale)
#    108718    0.142    0.000    0.260    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:1199(_set_is_copy)
# 5274/1758    0.065    0.000    0.260    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:799(rvs)
#    219612    0.227    0.000    0.250    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:1036(__contains__)
#      3261    0.240    0.000    0.242    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/rpy2/robjects/numpy2ri.py:42(numpy2ri)
#    217400    0.119    0.000    0.240    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:2507(is_datetime64_dtype)
#    108700    0.087    0.000    0.230    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/frame.py:1632(get_value)
#    326118    0.182    0.000    0.228    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:219(is_)
#    543536    0.227    0.000    0.227    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:238(_reset_identity)
#    108700    0.115    0.000    0.224    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:2501(is_int_or_datetime_dtype)
#    217419    0.130    0.000    0.222    0.000 {setattr}
#    218506    0.154    0.000    0.221    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:1079(_get_item_cache)
#    217400    0.220    0.000    0.220    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:1949(_possibly_castable)
#     68806    0.051    0.000    0.220    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2058(amax)
#    434836    0.218    0.000    0.218    0.000 {method 'fill' of 'numpy.ndarray' objects}
#    760936    0.210    0.000    0.210    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:228(dtype)
#      1758    0.003    0.000    0.205    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:3536(_rvs)
#    217400    0.116    0.000    0.204    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:112(to_dense)
#    326136    0.139    0.000    0.203    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2386(<genexpr>)
#    108701    0.113    0.000    0.198    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:44(__init__)
#    217418    0.153    0.000    0.191    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:2051(__finalize__)
#    109806    0.104    0.000    0.183    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/frame.py:1793(_getitem_column)
#    108701    0.151    0.000    0.176    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/numeric.py:1910(isscalar)
#      1758    0.058    0.000    0.175    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:850(stats)
#     68806    0.022    0.000    0.169    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:25(_amax)
#    108701    0.065    0.000    0.169    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:952(<lambda>)
#    108700    0.108    0.000    0.168    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:3752(_lcd_dtype)
#    108700    0.082    0.000    0.166    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:2547(is_float_dtype)
#     77640    0.054    0.000    0.165    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:1291(ravel)
#    217401    0.162    0.000    0.162    0.000 {pandas.lib.isscalar}
#      1758    0.008    0.000    0.151    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:725(_rvs)
#    381082    0.088    0.000    0.151    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/numerictypes.py:668(issubclass_)
#    217400    0.083    0.000    0.151    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:2607(is_null_slice)
#    108700    0.150    0.000    0.150    0.000 {pandas.lib.array_equivalent_object}
#    108700    0.146    0.000    0.146    0.000 {numpy.core.multiarray.putmask}
#    247231    0.143    0.000    0.143    0.000 {method 'take' of 'numpy.ndarray' objects}
#    108700    0.068    0.000    0.134    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2573(is_mixed_type)
#     67048    0.035    0.000    0.126    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:803(argsort)
#    543536    0.121    0.000    0.121    0.000 {built-in method __new__ of type object at 0x7f4530a57d00}
#    138513    0.048    0.000    0.119    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:53(take)
#    113370    0.118    0.000    0.118    0.000 {numpy.core.multiarray.zeros}
#    109788    0.055    0.000    0.115    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:366(_info_axis)
#    108712    0.115    0.000    0.115    0.000 {sorted}
#    108700    0.058    0.000    0.112    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:2516(is_timedelta64_dtype)
#    336329    0.108    0.000    0.108    0.000 {method 'update' of 'dict' objects}
#    108700    0.103    0.000    0.103    0.000 {pandas.index.convert_scalar}
#    108718    0.067    0.000    0.102    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:249(__array__)
#    113117    0.101    0.000    0.101    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#      1758    0.002    0.000    0.092    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:762(_rvs)
#    217401    0.092    0.000    0.092    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/series.py:275(_set_subtyp)
#     67048    0.091    0.000    0.091    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#    108718    0.069    0.000    0.090    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:2759(_clean_reindex_fill_method)
#    298319    0.090    0.000    0.090    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#      1758    0.090    0.000    0.090    0.000 {method 'chisquare' of 'mtrand.RandomState' objects}
#    978300    0.088    0.000    0.088    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:3748(<lambda>)
#    108700    0.087    0.000    0.087    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/frame.py:413(axes)
#      3261    0.009    0.000    0.075    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/singledispatch.py:209(wrapper)
#      2659    0.017    0.000    0.070    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:549(argsreduce)
#    218505    0.068    0.000    0.068    0.000 {method 'items' of 'dict' objects}
#    217418    0.059    0.000    0.059    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:220(shape)
#    434926    0.057    0.000    0.057    0.000 {pandas.algos.ensure_int64}
#      3261    0.027    0.000    0.057    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/rpy2/robjects/__init__.py:84(sexpvector_to_ro)
#    135262    0.052    0.000    0.056    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:763(_argcheck)
#    108700    0.043    0.000    0.053    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:5838(_ensure_has_len)
#    217418    0.051    0.000    0.051    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:115(fill_value)
#    326172    0.049    0.000    0.049    0.000 {pandas.lib.is_integer}
#      1758    0.002    0.000    0.048    0.000 {method 'var' of 'numpy.ndarray' objects}
#      1758    0.028    0.000    0.046    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:77(_var)
#    217418    0.046    0.000    0.046    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/frame.py:188(_constructor)
#    217401    0.045    0.000    0.045    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:3427(is_all_dates)
#      4348    0.008    0.000    0.043    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/rpy2/robjects/vectors.py:244(__getitem__)
#     10548    0.008    0.000    0.042    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:1852(all)
#      4417    0.009    0.000    0.034    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.py:1400(extract)
#    217454    0.033    0.000    0.033    0.000 {pandas.lib.is_float}
#    217400    0.031    0.000    0.031    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:3413(inferred_type)
#    217400    0.030    0.000    0.030    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/base.py:321(ndim)
#      1758    0.001    0.000    0.028    0.000 {method 'mean' of 'numpy.ndarray' objects}
#      1758    0.011    0.000    0.026    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:53(_mean)
#    108700    0.026    0.000    0.026    0.000 {any}
#    217400    0.025    0.000    0.025    0.000 {pandas.algos.ensure_object}
#    219612    0.023    0.000    0.023    0.000 {hash}
#    108736    0.023    0.000    0.023    0.000 {pandas.algos.ensure_platform_int}
#    108718    0.021    0.000    0.021    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:2738(_clean_fill_method)
#    191646    0.021    0.000    0.021    0.000 {iter}
#    110195    0.021    0.000    0.021    0.000 {method 'keys' of 'dict' objects}
#    108700    0.021    0.000    0.021    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/nanops.py:133(_get_fill_value)
#    108700    0.021    0.000    0.021    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2442(<genexpr>)
#      5274    0.004    0.000    0.019    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:1726(product)
#       124    0.001    0.000    0.018    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/iostream.py:207(write)
#      3261    0.014    0.000    0.018    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/rpy2/robjects/vectors.py:231(__init__)
#      1758    0.008    0.000    0.018    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:501(valarray)
#        44    0.000    0.000    0.016    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/iostream.py:151(flush)
#    108700    0.014    0.000    0.014    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:586(nlevels)
#      1087    0.004    0.000    0.014    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/rpy2/robjects/vectors.py:535(__init__)
#        44    0.001    0.000    0.014    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/session.py:589(send)
#      1776    0.003    0.000    0.013    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:1772(any)
#         1    0.010    0.010    0.012    0.012 /home/beingzy/anaconda/lib/python2.7/site-packages/networkx/classes/graph.py:719(add_edges_from)
#      2174    0.004    0.000    0.012    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/rpy2/robjects/vectors.py:445(__init__)
#      1758    0.012    0.000    0.012    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:3548(_stats)
#      1758    0.009    0.000    0.012    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:1938(_reduce_func)
#      1758    0.003    0.000    0.010    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/lib/type_check.py:75(asfarray)
#        18    0.000    0.000    0.010    0.001 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/frame.py:1810(_getitem_array)
#      8790    0.009    0.000    0.009    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      3261    0.006    0.000    0.009    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/singledispatch.py:173(dispatch)
#      3516    0.007    0.000    0.009    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:43(_count_reduce_items)
#      3560    0.003    0.000    0.008    0.000 {map}
#      5274    0.003    0.000    0.008    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:125(reshape)
#        44    0.000    0.000    0.007    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/session.py:530(serialize)
#      1758    0.002    0.000    0.006    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/numeric.py:141(ones)
#      3516    0.002    0.000    0.006    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.py:1449(place)
#       176    0.000    0.000    0.005    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/session.py:84(<lambda>)
#        44    0.000    0.000    0.005    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/session.py:496(msg)
#      1105    0.002    0.000    0.005    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:992(__iter__)
#       176    0.000    0.000    0.005    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/zmq/utils/jsonapi.py:31(dumps)
#      1758    0.001    0.000    0.005    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2142(amin)
#     11113    0.005    0.000    0.005    0.000 {range}
#        44    0.000    0.000    0.005    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/session.py:493(msg_header)
#      3516    0.004    0.000    0.004    0.000 {numpy.lib._compiled_base._insert}
#       176    0.001    0.000    0.004    0.000 /home/beingzy/anaconda/lib/python2.7/json/__init__.py:193(dumps)
#      4417    0.002    0.000    0.004    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:1380(nonzero)
#      1087    0.004    0.000    0.004    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/networkx/classes/graph.py:943(neighbors)
#      6522    0.004    0.000    0.004    0.000 {method 'do_slot' of 'rpy2.rinterface.Sexp' objects}
#       176    0.000    0.000    0.004    0.000 /home/beingzy/anaconda/lib/python2.7/json/encoder.py:186(encode)
#        44    0.000    0.000    0.004    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/session.py:441(msg_id)
#      1758    0.001    0.000    0.003    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:28(_amin)
#        18    0.000    0.000    0.003    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:998(_convert_to_indexer)
#        44    0.001    0.000    0.003    0.000 /home/beingzy/anaconda/lib/python2.7/uuid.py:579(uuid4)
#      3261    0.003    0.000    0.003    0.000 /home/beingzy/anaconda/lib/python2.7/weakref.py:314(__getitem__)
#       176    0.001    0.000    0.003    0.000 /home/beingzy/anaconda/lib/python2.7/json/encoder.py:212(iterencode)
#      1758    0.003    0.000    0.003    0.000 {numpy.core.multiarray.copyto}
#        18    0.000    0.000    0.002    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:3168(_slice_take_blocks_ax0)
#      1758    0.001    0.000    0.002    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/numerictypes.py:611(obj2sctype)
#      6522    0.002    0.000    0.002    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/rpy2/robjects/vectors.py:42(__init__)
#      1144    0.001    0.000    0.002    0.000 /home/beingzy/anaconda/lib/python2.7/json/encoder.py:33(encode_basestring)
#        18    0.000    0.000    0.002    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:1649(get_indexer)
#      2207    0.002    0.000    0.002    0.000 {max}
#        44    0.002    0.000    0.002    0.000 /home/beingzy/anaconda/lib/python2.7/ctypes/__init__.py:52(create_string_buffer)
#      1758    0.001    0.000    0.001    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#      1776    0.001    0.000    0.001    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.py:275(wrap_function)
#      3261    0.001    0.000    0.001    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/rpy2/robjects/vectors.py:141(__init__)
#      1758    0.001    0.000    0.001    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:1462(shape)
#        44    0.000    0.000    0.001    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/session.py:515(sign)
#      6361    0.001    0.000    0.001    0.000 {method 'pop' of 'dict' objects}
#        44    0.000    0.000    0.001    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/zmq/sugar/socket.py:285(send_multipart)
#      1144    0.001    0.000    0.001    0.000 {method 'sub' of '_sre.SRE_Pattern' objects}
#        44    0.001    0.000    0.001    0.000 /home/beingzy/anaconda/lib/python2.7/uuid.py:101(__init__)
#        18    0.000    0.000    0.001    0.000 learning_dist_metrics/ldm.py:260(vec_normalized)
#        44    0.000    0.000    0.001    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/iostream.py:123(_flush_from_subprocesses)
#       308    0.001    0.000    0.001    0.000 {method 'send' of 'zmq.backend.cython.socket.Socket' objects}
#      1200    0.001    0.000    0.001    0.000 {method 'startswith' of 'str' objects}
#      1776    0.001    0.000    0.001    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.py:127(_check_unknown_options)
#        44    0.000    0.000    0.001    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/session.py:195(msg_header)
#       124    0.000    0.000    0.001    0.000 {method 'decode' of 'str' objects}
#      1758    0.001    0.000    0.001    0.000 <string>:8(_parse_args_stats)
#        12    0.000    0.000    0.001    0.000 GWDLearner.py:409(drawDropouts)
#        44    0.000    0.000    0.000    0.000 {built-in method now}
#         9    0.000    0.000    0.000    0.000 GWDLearner.py:369(get_fit_score)
#        44    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/zmq/sugar/poll.py:77(poll)
#       848    0.000    0.000    0.000    0.000 {method 'tostring' of 'numpy.ndarray' objects}
#        14    0.000    0.000    0.000    0.000 {method 'choice' of 'mtrand.RandomState' objects}
#      1758    0.000    0.000    0.000    0.000 <string>:5(_parse_args_rvs)
#       124    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/encodings/utf_8.py:15(decode)
#       168    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/iostream.py:102(_check_mp_mode)
#        44    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/hmac.py:88(copy)
#        44    0.000    0.000    0.000    0.000 {zmq.backend.cython._poll.zmq_poll}
#       176    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#       572    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/utils/traitlets.py:395(__get__)
#       176    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/hmac.py:83(update)
#        44    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/zmq/sugar/attrsettr.py:35(__getattr__)
#      1794    0.000    0.000    0.000    0.000 {callable}
#       176    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/json/encoder.py:101(__init__)
#        44    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/iostream.py:96(_is_master_thread)
#        44    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/iostream.py:238(_flush_buffer)
#        44    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/session.py:200(extract_header)
#       220    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HASH' objects}
#        44    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/hmac.py:119(hexdigest)
#       124    0.000    0.000    0.000    0.000 {_codecs.utf_8_decode}
#       212    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/iostream.py:93(_is_master_process)
#        18    0.000    0.000    0.000    0.000 {pandas.algos.take_2d_axis0_float64_float64}
#        36    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:3931(_get_blkno_placements)
#       374    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#       108    0.000    0.000    0.000    0.000 {round}
#        18    0.000    0.000    0.000    0.000 {method 'get_indexer' of 'pandas.index.IndexEngine' objects}
#       132    0.000    0.000    0.000    0.000 {method 'encode' of 'unicode' objects}
#        44    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/utils/jsonutil.py:102(date_default)
#        44    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/uuid.py:197(__str__)
#        18    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:162(_convert_scalar_indexer)
#        14    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2259(prod)
#        44    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/hmac.py:100(_current)
#       124    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        36    0.000    0.000    0.000    0.000 {pandas.algos.take_1d_int64_int64}
#         3    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/codeop.py:132(__call__)
#        20    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:1559(get_loc)
#         3    0.000    0.000    0.000    0.000 {compile}
#        44    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#        14    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:34(_prod)
#        18    0.000    0.000    0.000    0.000 learning_dist_metrics/ldm.py:41(__init__)
#       132    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HASH' objects}
#        18    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/getlimits.py:93(__new__)
#        65    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/json/encoder.py:37(replace)
#        44    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/iostream.py:247(_new_buffer)
#        18    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:4457(_preprocess_slice_or_indexer)
#        18    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:1789(_possibly_promote)
#        44    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/threading.py:1152(currentThread)
#        18    0.000    0.000    0.000    0.000 {pandas.lib.get_blkno_indexers}
#         9    0.000    0.000    0.000    0.000 GWDLearner.py:586(<dictcomp>)
#        18    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/series.py:379(__len__)
#        44    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/singledispatch.py:132(_find_impl)
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2844(get)
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/singledispatch.py:91(_compose_mro)
#        18    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:1603(convert_to_index_sliceable)
#        44    0.000    0.000    0.000    0.000 {locals}
#       160    0.000    0.000    0.000    0.000 {time.time}
#        18    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/frame.py:417(shape)
#        18    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:764(_convert_scalar_indexer)
#        18    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:743(is_integer)
#       4/1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/singledispatch.py:46(_c3_mro)
#        20    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas.index.IndexEngine' objects}
#         1    0.000    0.000    0.000    0.000 <ipython-input-4-83f818a3e67e>:5(<module>)
#        44    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#       256    0.000    0.000    0.000    0.000 {posix.getpid}
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2872(iget)
#        18    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/common.py:2477(is_dtype_equal)
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/frame.py:2096(_box_item_values)
#        44    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/threading.py:983(ident)
#       432    0.000    0.000    0.000    0.000 GWDLearner.py:428(<lambda>)
#        44    0.000    0.000    0.000    0.000 {method 'count' of 'list' objects}
#        44    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:978(inferred_type)
#        36    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        44    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/hmac.py:30(__init__)
#       112    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        12    0.000    0.000    0.000    0.000 GWDLearner.py:304(init_dict_list)
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/frame.py:2103(_box_col_values)
#         9    0.000    0.000    0.000    0.000 GWDLearner.py:646(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/series.py:225(from_array)
#        65    0.000    0.000    0.000    0.000 {method 'group' of '_sre.SRE_Match' objects}
#        44    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#        44    0.000    0.000    0.000    0.000 {thread.get_ident}
#         4    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/singledispatch.py:19(_c3_merge)
#        18    0.000    0.000    0.000    0.000 {min}
#        36    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:1093(_set_as_cached)
#        44    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#        18    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:1722(is_nested_tuple)
#         8    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/singledispatch.py:100(is_related)
#        44    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/utils/py3compat.py:11(no_code)
#        44    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#        18    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:1050(__getitem__)
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/networkx/classes/graph.py:175(__init__)
#         3    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/core/hooks.py:127(__call__)
#        18    0.000    0.000    0.000    0.000 learning_dist_metrics/ldm.py:195(get_transform_matrix)
#        36    0.000    0.000    0.000    0.000 {pandas.lib.is_bool}
#         3    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/utils/ipstruct.py:125(__getattr__)
#        19    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:259(dtype)
#         1    0.000    0.000    0.000    0.000 <ipython-input-4-83f818a3e67e>:9(<module>)
#         3    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:1107(user_global_ns)
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:259(iget)
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/weakref.py:320(__setitem__)
#         1    0.000    0.000    0.000    0.000 {pandas.lib.checknull}
#         3    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/core/hooks.py:192(pre_run_code_hook)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
import json

root_path = os.getcwd()
data_path = root_path + "/results/"

# extract component of interest
_, _, info_pkg = res

# create output connection
outfile = data_path + "beta_test_20150826_v01.json"
out_conn = open(outfile, 'w')
print "Writing out information..."
out_conn.write( json.dumps(info_pkg) )
out_conn.close()
# Out:
# Writing out information...

# %%
for i in range(10):
    
    print "%d / 10 \n" % i
    
    res = learning_wrapper(profile_df=profile_df, friends_pair=friends_ls, max_iter=50,\
                           k=2, c=0.1, dropout_rate=0.2, fit_rayleigh=True, verbose=True, \
                           buffer_group_enabled=False)
    # extract component of interest
    #res

    # create output connection
    out_fname = data_path + "beta_test_20150826_buffer_" + i + ".json"
    out_conn = open(outfile, 'w')
    print "Writing out information..."
    out_conn.write( json.dumps(res) )
    out_conn.close()
# Out:
# 0 / 10
#
# Initiating ...
# 1 iteration is in processing ...
# --- 34.02 seconds ---
# --- 24.16 seconds ---
# 2 iteration is in processing ...
# --- 38.87 seconds ---
# --- 28.46 seconds ---
# 3 iteration is in processing ...
# --- 22.80 seconds ---
# --- 31.17 seconds ---
# ** dropout is activating ...
#
# 4 iteration is in processing ...
# --- 35.16 seconds ---
# --- 40.25 seconds ---
# ** dropout is activating ...
#
# 5 iteration is in processing ...
# --- 29.26 seconds ---
# --- 23.19 seconds ---
# ** dropout is activating ...
#
# 6 iteration is in processing ...
# --- 83.99 seconds ---
# --- 25.55 seconds ---
# ** dropout is activating ...
#
# 7 iteration is in processing ...
# --- 43.39 seconds ---
# --- 26.95 seconds ---
# ** dropout is activating ...
#
# 8 iteration is in processing ...
# --- 31.09 seconds ---
# --- 44.37 seconds ---
# ** dropout is activating ...
#
# 9 iteration is in processing ...
# --- 23.82 seconds ---
# --- 25.51 seconds ---
# ** dropout is activating ...
#
# 10 iteration is in processing ...
# --- 27.21 seconds ---
# --- 34.70 seconds ---
# 11 iteration is in processing ...
# --- 27.49 seconds ---
# --- 87.48 seconds ---
# ** dropout is activating ...
#
# 12 iteration is in processing ...
# --- 34.14 seconds ---
# --- 78.85 seconds ---
# ** dropout is activating ...
#
# 13 iteration is in processing ...
# --- 22.14 seconds ---
# --- 30.38 seconds ---
# ** dropout is activating ...
#
# 14 iteration is in processing ...
# --- 30.01 seconds ---
# --- 28.80 seconds ---
# 15 iteration is in processing ...
# --- 37.79 seconds ---
# --- 49.21 seconds ---
# ** dropout is activating ...
#
# 16 iteration is in processing ...
# --- 21.89 seconds ---
# --- 35.87 seconds ---
# ** dropout is activating ...
#
# 17 iteration is in processing ...
# --- 26.23 seconds ---
# --- 29.30 seconds ---
# ** dropout is activating ...
#
# 18 iteration is in processing ...
# --- 35.89 seconds ---
# --- 43.85 seconds ---
# ** dropout is activating ...
#
# 19 iteration is in processing ...
# --- 41.75 seconds ---
# --- 28.18 seconds ---
# ** dropout is activating ...
#
# 20 iteration is in processing ...
# --- 37.18 seconds ---
# --- 32.98 seconds ---
# ** dropout is activating ...
#
# 21 iteration is in processing ...
# --- 23.87 seconds ---
# --- 35.90 seconds ---
# ** dropout is activating ...
#
# 22 iteration is in processing ...
# --- 27.79 seconds ---
# --- 55.75 seconds ---
# ** dropout is activating ...
#
# 23 iteration is in processing ...
# --- 27.64 seconds ---
# --- 29.49 seconds ---
# ** dropout is activating ...
#
# 24 iteration is in processing ...
# --- 30.48 seconds ---
# --- 25.22 seconds ---
# ** dropout is activating ...
#
# 25 iteration is in processing ...
# --- 29.13 seconds ---
# --- 30.49 seconds ---
# ** dropout is activating ...
#
# 26 iteration is in processing ...
# --- 24.99 seconds ---
# --- 55.79 seconds ---
# ** dropout is activating ...
#
# 27 iteration is in processing ...
# --- 37.73 seconds ---
# --- 22.79 seconds ---
# ** dropout is activating ...
#
# 28 iteration is in processing ...
# --- 26.12 seconds ---
# --- 43.96 seconds ---
# ** dropout is activating ...
#
# 29 iteration is in processing ...
# --- 23.86 seconds ---
# --- 41.70 seconds ---
# ** dropout is activating ...
#
# 30 iteration is in processing ...
# --- 26.11 seconds ---
# --- 38.55 seconds ---
# ** dropout is activating ...
#
# 31 iteration is in processing ...
# --- 38.29 seconds ---
# --- 25.29 seconds ---
# ** dropout is activating ...
#
# 32 iteration is in processing ...
# --- 34.12 seconds ---
# --- 62.43 seconds ---
# ** dropout is activating ...
#
# 33 iteration is in processing ...
# --- 22.41 seconds ---
# --- 31.77 seconds ---
# ** dropout is activating ...
#
# 34 iteration is in processing ...
# --- 37.70 seconds ---
# --- 33.26 seconds ---
# ** dropout is activating ...
#
# 35 iteration is in processing ...
# --- 25.21 seconds ---
# --- 26.63 seconds ---
# ** dropout is activating ...
#
# 36 iteration is in processing ...
# --- 29.06 seconds ---
# --- 51.31 seconds ---
# ** dropout is activating ...
#
# 37 iteration is in processing ...
# --- 28.04 seconds ---
# --- 27.85 seconds ---
# ** dropout is activating ...
#
# 38 iteration is in processing ...
# --- 28.82 seconds ---
# --- 36.64 seconds ---
# ** dropout is activating ...
#
# 39 iteration is in processing ...
# --- 35.01 seconds ---
# --- 29.58 seconds ---
# ** dropout is activating ...
#
# 40 iteration is in processing ...
# --- 28.71 seconds ---
# --- 77.59 seconds ---
# ** dropout is activating ...
#
# 41 iteration is in processing ...
# --- 24.06 seconds ---
# --- 38.95 seconds ---
# ** dropout is activating ...
#
# 42 iteration is in processing ...
# --- 30.99 seconds ---
# --- 29.12 seconds ---
# ** dropout is activating ...
#
# 43 iteration is in processing ...
# --- 27.15 seconds ---
# --- 42.60 seconds ---
# ** dropout is activating ...
#
# 44 iteration is in processing ...
# --- 27.09 seconds ---
# --- 75.65 seconds ---
# ** dropout is activating ...
#
# 45 iteration is in processing ...
# --- 19.61 seconds ---
# --- 49.05 seconds ---
# ** dropout is activating ...
#
# 46 iteration is in processing ...
# --- 26.05 seconds ---
# --- 36.83 seconds ---
# ** dropout is activating ...
#
# 47 iteration is in processing ...
# --- 26.68 seconds ---
# --- 26.73 seconds ---
# ** dropout is activating ...
#
# 48 iteration is in processing ...
# --- 22.31 seconds ---
# --- 52.27 seconds ---
# 49 iteration is in processing ...
# --- 24.69 seconds ---
# --- 91.46 seconds ---
# ** dropout is activating ...
#
# 50 iteration is in processing ...
# --- 27.61 seconds ---
# --- 80.77 seconds ---
# ** dropout is activating ...
#
# 51 iteration is in processing ...
# --- 25.37 seconds ---
# --- 21.23 seconds ---
# ** dropout is activating ...
#
# 52 iteration is in processing ...
# --- 26.09 seconds ---
# --- 29.06 seconds ---
# ** dropout is activating ...
#
# 53 iteration is in processing ...
# --- 32.37 seconds ---
# --- 27.76 seconds ---
# ** dropout is activating ...
#
# 54 iteration is in processing ...
# --- 24.90 seconds ---
# --- 29.16 seconds ---
# ** dropout is activating ...
#
# 55 iteration is in processing ...
# --- 76.27 seconds ---
# --- 35.71 seconds ---
# ** dropout is activating ...
#
# 56 iteration is in processing ...
# --- 26.26 seconds ---
# --- 48.82 seconds ---
# ** dropout is activating ...
#
# 57 iteration is in processing ...
# --- 26.45 seconds ---
# --- 55.46 seconds ---
# ** dropout is activating ...
#
# 58 iteration is in processing ...
# --- 28.99 seconds ---
# --- 37.18 seconds ---
# ** dropout is activating ...
#
# 59 iteration is in processing ...
# --- 26.86 seconds ---
# --- 38.43 seconds ---
# ** dropout is activating ...
#
# 60 iteration is in processing ...
# --- 23.38 seconds ---
# --- 34.53 seconds ---
# ** dropout is activating ...
#
# 61 iteration is in processing ...
# --- 32.14 seconds ---
# --- 65.79 seconds ---
# ** dropout is activating ...
#
# 62 iteration is in processing ...
# --- 27.50 seconds ---
# --- 39.66 seconds ---
# ** dropout is activating ...
#
# 63 iteration is in processing ...
# --- 24.95 seconds ---
# --- 33.06 seconds ---
# ** dropout is activating ...
#
# 64 iteration is in processing ...
# --- 28.96 seconds ---
# --- 39.88 seconds ---
# ** dropout is activating ...
#
# 65 iteration is in processing ...
# --- 40.37 seconds ---
# --- 25.19 seconds ---
# ** dropout is activating ...
#
# 66 iteration is in processing ...
# --- 27.90 seconds ---
# --- 54.56 seconds ---
# ** dropout is activating ...
#
# 67 iteration is in processing ...
# --- 40.57 seconds ---
# --- 29.28 seconds ---
# ** dropout is activating ...
#
# 68 iteration is in processing ...
# --- 30.16 seconds ---
# --- 32.95 seconds ---
# ** dropout is activating ...
#
# 69 iteration is in processing ...
# --- 28.20 seconds ---
# --- 29.21 seconds ---
# ** dropout is activating ...
#
# 70 iteration is in processing ...
# --- 31.47 seconds ---
# --- 35.66 seconds ---
# ** dropout is activating ...
#
# 71 iteration is in processing ...
# --- 29.45 seconds ---
# --- 24.04 seconds ---
# ** dropout is activating ...
#
# 72 iteration is in processing ...
# --- 30.38 seconds ---
# --- 34.72 seconds ---
# ** dropout is activating ...
#
# 73 iteration is in processing ...
# --- 29.43 seconds ---
# --- 31.76 seconds ---
# ** dropout is activating ...
#
# 74 iteration is in processing ...
# --- 30.85 seconds ---
# --- 43.80 seconds ---
# ** dropout is activating ...
#
# 75 iteration is in processing ...
# --- 29.25 seconds ---
# --- 27.96 seconds ---
# ** dropout is activating ...
#
# 76 iteration is in processing ...
# --- 23.70 seconds ---
# --- 31.60 seconds ---
# ** dropout is activating ...
#
# 77 iteration is in processing ...
# --- 20.73 seconds ---
# --- 26.58 seconds ---
# ** dropout is activating ...
#
# 78 iteration is in processing ...
# --- 23.60 seconds ---
# --- 31.96 seconds ---
# ** dropout is activating ...
#
# 79 iteration is in processing ...
# --- 31.99 seconds ---
# --- 36.79 seconds ---
# ** dropout is activating ...
#
# 80 iteration is in processing ...
# --- 26.66 seconds ---
# --- 63.45 seconds ---
# ** dropout is activating ...
#
# 81 iteration is in processing ...
# --- 26.58 seconds ---
# --- 40.53 seconds ---
# ** dropout is activating ...
#
# 82 iteration is in processing ...
# --- 20.80 seconds ---
# --- 55.17 seconds ---
# ** dropout is activating ...
#
# 83 iteration is in processing ...
# --- 25.12 seconds ---
# --- 30.43 seconds ---
# ** dropout is activating ...
#
# 84 iteration is in processing ...
# --- 27.97 seconds ---
# --- 36.10 seconds ---
# ** dropout is activating ...
#
# 85 iteration is in processing ...
# --- 24.50 seconds ---
# --- 40.23 seconds ---
# ** dropout is activating ...
#
# 86 iteration is in processing ...
# --- 26.61 seconds ---
# --- 55.11 seconds ---
# 87 iteration is in processing ...
# --- 26.18 seconds ---
# --- 57.08 seconds ---
# ** dropout is activating ...
#
# 88 iteration is in processing ...
# --- 26.15 seconds ---
# --- 51.09 seconds ---
# ** dropout is activating ...
#
# 89 iteration is in processing ...
# --- 22.24 seconds ---
# --- 42.05 seconds ---
# ** dropout is activating ...
#
# 90 iteration is in processing ...
# --- 24.05 seconds ---
# --- 50.15 seconds ---
# ** dropout is activating ...
#
# 91 iteration is in processing ...
# --- 25.98 seconds ---
# --- 33.70 seconds ---
# ** dropout is activating ...
#
# 92 iteration is in processing ...
# --- 29.59 seconds ---
# --- 49.42 seconds ---
# ** dropout is activating ...
#
# 93 iteration is in processing ...
# --- 26.76 seconds ---
# --- 24.07 seconds ---
# ** dropout is activating ...
#
# 94 iteration is in processing ...
# --- 27.88 seconds ---
# --- 60.03 seconds ---
# ** dropout is activating ...
#
# 95 iteration is in processing ...
# --- 25.99 seconds ---
# --- 58.25 seconds ---
# ** dropout is activating ...
#
# 96 iteration is in processing ...
# --- 32.60 seconds ---
# --- 47.96 seconds ---
# ** dropout is activating ...
#
# 97 iteration is in processing ...
# --- 25.88 seconds ---
# --- 70.66 seconds ---
# ** dropout is activating ...
#
# 98 iteration is in processing ...
# --- 25.23 seconds ---
# --- 31.92 seconds ---
# ** dropout is activating ...
#
# 99 iteration is in processing ...
# --- 35.12 seconds ---
# --- 36.44 seconds ---
# ** dropout is activating ...
#
# 100 iteration is in processing ...
# --- 22.94 seconds ---
# --- 51.68 seconds ---
# ** dropout is activating ...
#
# 101 iteration is in processing ...
# --- 22.98 seconds ---
# --- 25.86 seconds ---
# ** dropout is activating ...
#
# 102 iteration is in processing ...
# --- 32.28 seconds ---
# --- 41.43 seconds ---
# ** dropout is activating ...
#
# 103 iteration is in processing ...
# --- 26.13 seconds ---
# --- 21.13 seconds ---
# ** dropout is activating ...
#
# 104 iteration is in processing ...
# --- 24.69 seconds ---
# --- 66.04 seconds ---
# ** dropout is activating ...
#
# 105 iteration is in processing ...
# --- 24.93 seconds ---
# --- 24.85 seconds ---
# ** dropout is activating ...
#
# 106 iteration is in processing ...
# --- 35.51 seconds ---
# --- 50.06 seconds ---
# ** dropout is activating ...
#
# 107 iteration is in processing ...
# --- 23.94 seconds ---
# --- 41.06 seconds ---
# ** dropout is activating ...
#
# 108 iteration is in processing ...
# --- 24.71 seconds ---
# --- 43.63 seconds ---
# ** dropout is activating ...
#
# 109 iteration is in processing ...
# --- 62.85 seconds ---
# --- 40.86 seconds ---
# 110 iteration is in processing ...
# --- 20.00 seconds ---
# --- 45.20 seconds ---
# 111 iteration is in processing ...
# --- 22.13 seconds ---
# --- 27.19 seconds ---
# ** dropout is activating ...
#
# 112 iteration is in processing ...
# --- 23.48 seconds ---
# --- 29.00 seconds ---
# ** dropout is activating ...
#
# 113 iteration is in processing ...
# --- 23.75 seconds ---
# --- 35.62 seconds ---
# ** dropout is activating ...
#
# 114 iteration is in processing ...
# --- 26.27 seconds ---
# --- 67.25 seconds ---
# ** dropout is activating ...
#
# 115 iteration is in processing ...
# --- 27.83 seconds ---
# --- 27.84 seconds ---
# ** dropout is activating ...
#
# 116 iteration is in processing ...
# --- 23.46 seconds ---
# --- 31.15 seconds ---
# ** dropout is activating ...
#
# 117 iteration is in processing ...
# --- 27.99 seconds ---
# --- 33.24 seconds ---
# ** dropout is activating ...
#
# 118 iteration is in processing ...
# --- 22.21 seconds ---
# --- 35.73 seconds ---
# ** dropout is activating ...
#
# 119 iteration is in processing ...
# --- 24.94 seconds ---
# --- 34.51 seconds ---
# ** dropout is activating ...
#
# 120 iteration is in processing ...
# --- 24.67 seconds ---
# --- 48.64 seconds ---
# ** dropout is activating ...
#
# 121 iteration is in processing ...
# --- 23.74 seconds ---
# --- 31.93 seconds ---
# ** dropout is activating ...
#
# 122 iteration is in processing ...
# --- 25.87 seconds ---
# --- 48.96 seconds ---
# ** dropout is activating ...
#
# 123 iteration is in processing ...
# --- 57.05 seconds ---
# --- 25.39 seconds ---
# ** dropout is activating ...
#
# 124 iteration is in processing ...
# --- 29.26 seconds ---
# --- 31.64 seconds ---
# ** dropout is activating ...
#
# 125 iteration is in processing ...
# --- 23.87 seconds ---
# --- 26.50 seconds ---
# ** dropout is activating ...
#
# 126 iteration is in processing ...
# --- 22.21 seconds ---
# --- 56.98 seconds ---
# ** dropout is activating ...
#
# 127 iteration is in processing ...
# --- 26.40 seconds ---
# --- 59.17 seconds ---
# ** dropout is activating ...
#
# 128 iteration is in processing ...
# --- 26.43 seconds ---
# --- 66.66 seconds ---
# ** dropout is activating ...
#
# 129 iteration is in processing ...
# --- 19.90 seconds ---
# --- 30.36 seconds ---
# ** dropout is activating ...
#
# 130 iteration is in processing ...
# --- 25.80 seconds ---
# --- 30.12 seconds ---
# 131 iteration is in processing ...
# --- 26.90 seconds ---
# --- 64.43 seconds ---
# ** dropout is activating ...
#
# 132 iteration is in processing ...
# --- 23.59 seconds ---
# --- 76.77 seconds ---
# ** dropout is activating ...
#
# 133 iteration is in processing ...
# --- 22.67 seconds ---
# --- 26.65 seconds ---
# ** dropout is activating ...
#
# 134 iteration is in processing ...
# --- 20.68 seconds ---
# --- 48.61 seconds ---
# ** dropout is activating ...
#
# 135 iteration is in processing ...
# --- 26.85 seconds ---
# --- 56.69 seconds ---
# ** dropout is activating ...
#
# 136 iteration is in processing ...
# --- 29.00 seconds ---
# --- 30.39 seconds ---
# ** dropout is activating ...
#
# 137 iteration is in processing ...
# --- 23.77 seconds ---
# --- 26.38 seconds ---
# ** dropout is activating ...
#
# 138 iteration is in processing ...
# --- 33.18 seconds ---
# --- 50.43 seconds ---
# ** dropout is activating ...
#
# 139 iteration is in processing ...
# --- 23.91 seconds ---
# --- 38.63 seconds ---
# ** dropout is activating ...
#
# 140 iteration is in processing ...
# --- 27.41 seconds ---
# --- 27.74 seconds ---
# ** dropout is activating ...
#
# 141 iteration is in processing ...
# --- 26.32 seconds ---
# --- 42.16 seconds ---
# ** dropout is activating ...
#
# 142 iteration is in processing ...
# --- 31.51 seconds ---
# --- 33.19 seconds ---
# ** dropout is activating ...
#
# 143 iteration is in processing ...
# --- 22.52 seconds ---
# --- 35.88 seconds ---
# ** dropout is activating ...
#
# 144 iteration is in processing ...
# --- 33.02 seconds ---
# --- 24.94 seconds ---
# ** dropout is activating ...
#
# 145 iteration is in processing ...
# --- 24.15 seconds ---
# --- 49.69 seconds ---
# ** dropout is activating ...
#
# 146 iteration is in processing ...
# --- 27.40 seconds ---
# --- 46.80 seconds ---
# ** dropout is activating ...
#
# 147 iteration is in processing ...
# --- 23.73 seconds ---
# --- 30.31 seconds ---
# ** dropout is activating ...
#
# 148 iteration is in processing ...
# --- 23.30 seconds ---
# --- 29.04 seconds ---
# ** dropout is activating ...
#
# 149 iteration is in processing ...
# --- 32.00 seconds ---
# --- 27.72 seconds ---
# ** dropout is activating ...
#
# 150 iteration is in processing ...
# --- 30.20 seconds ---
# --- 40.92 seconds ---
# ** dropout is activating ...
#
# 151 iteration is in processing ...
# --- 27.52 seconds ---
# --- 33.01 seconds ---
# ** dropout is activating ...
#
# 152 iteration is in processing ...
# --- 27.59 seconds ---
# --- 39.60 seconds ---
# ** dropout is activating ...
#
# 153 iteration is in processing ...
# --- 25.16 seconds ---
# --- 34.21 seconds ---
# ** dropout is activating ...
#
# 154 iteration is in processing ...
# --- 26.07 seconds ---
# --- 45.37 seconds ---
# ** dropout is activating ...
#
# 155 iteration is in processing ...
# --- 19.97 seconds ---
# --- 56.15 seconds ---
# ** dropout is activating ...
#
# 156 iteration is in processing ...
# --- 25.86 seconds ---
# --- 42.13 seconds ---
# ** dropout is activating ...
#
# 157 iteration is in processing ...
# --- 31.29 seconds ---
# --- 34.75 seconds ---
# ** dropout is activating ...
#
# 158 iteration is in processing ...
# --- 38.35 seconds ---
# --- 62.13 seconds ---
# ** dropout is activating ...
#
# 159 iteration is in processing ...
# --- 25.71 seconds ---
# --- 29.38 seconds ---
# ** dropout is activating ...
#
# 160 iteration is in processing ...
# --- 28.97 seconds ---
# --- 63.01 seconds ---
# ** dropout is activating ...
#
# 161 iteration is in processing ...
# --- 24.32 seconds ---
# --- 30.91 seconds ---
# ** dropout is activating ...
#
# 162 iteration is in processing ...
# --- 23.77 seconds ---
# --- 47.73 seconds ---
# ** dropout is activating ...
#
# 163 iteration is in processing ...
# --- 24.32 seconds ---
# --- 68.12 seconds ---
# ** dropout is activating ...
#
# 164 iteration is in processing ...
# --- 33.68 seconds ---
# --- 35.83 seconds ---
# ** dropout is activating ...
#
# 165 iteration is in processing ...
# --- 25.22 seconds ---
# --- 29.50 seconds ---
# ** dropout is activating ...
#
# 166 iteration is in processing ...
# --- 51.08 seconds ---
# --- 47.97 seconds ---
# ** dropout is activating ...
#
# 167 iteration is in processing ...
# --- 26.93 seconds ---
# --- 25.45 seconds ---
# ** dropout is activating ...
#
# 168 iteration is in processing ...
# --- 22.23 seconds ---
# --- 53.10 seconds ---
# ** dropout is activating ...
#
# 169 iteration is in processing ...
# --- 22.52 seconds ---
# --- 43.93 seconds ---
# ** dropout is activating ...
#
# 170 iteration is in processing ...
# --- 57.40 seconds ---
# --- 45.53 seconds ---
# ** dropout is activating ...
#
# 171 iteration is in processing ...
# --- 24.80 seconds ---
# --- 42.83 seconds ---
# ** dropout is activating ...
#
# 172 iteration is in processing ...
# --- 29.36 seconds ---
# --- 36.94 seconds ---
# ** dropout is activating ...
#
# 173 iteration is in processing ...
# --- 23.69 seconds ---
# --- 30.62 seconds ---
# ** dropout is activating ...
#
# 174 iteration is in processing ...
# --- 26.68 seconds ---
# --- 49.83 seconds ---
# ** dropout is activating ...
#
# 175 iteration is in processing ...
# --- 26.06 seconds ---
# --- 33.14 seconds ---
# ** dropout is activating ...
#
# 176 iteration is in processing ...
# --- 23.48 seconds ---
# --- 29.14 seconds ---
# ** dropout is activating ...
#
# 177 iteration is in processing ...
# --- 20.82 seconds ---
# --- 29.04 seconds ---
# ** dropout is activating ...
#
# 178 iteration is in processing ...
# --- 23.53 seconds ---
# --- 55.32 seconds ---
# ** dropout is activating ...
#
# 179 iteration is in processing ...
# --- 59.49 seconds ---
# --- 61.29 seconds ---
# ** dropout is activating ...
#
# 180 iteration is in processing ...
# --- 18.07 seconds ---
# --- 29.17 seconds ---
# ** dropout is activating ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-a731c6d6b8d3> in <module>()
#       8
#       9     # create output connection
# ---> 10     out_fname = data_path + "beta_test_20150826_buffer_" + i + ".json"
#      11     out_conn = open(outfile, 'w')
#      12     print "Writing out information..."
#
# TypeError: cannot concatenate 'str' and 'int' objects

# %%
for item in range(10):
    
    print "%d / 10 \n" % i
    
    res = learning_wrapper(profile_df=profile_df, friends_pair=friends_ls, max_iter=50,\
                           k=2, c=0.1, dropout_rate=0.2, fit_rayleigh=True, verbose=False, \
                           buffer_group_enabled=False)
    # extract component of interest
    _, _, info_pkg = res

    # create output connection
    out_fname = data_path + "beta_test_20150826_nobuffer_%d.json" % i
    out_conn = open(outfile, 'w')
    print "Writing out information..."
    out_conn.write( json.dumps(info_pkg) )
    out_conn.close()

# %%
a, b =res

# %%
a.keys()
# Out:
# ['fit_group', 'buffer_group', 'dist_metrics', 'fs_hist']

# %%
len(a['fit_group'][0]), len(a['fit_group'][1]), len(a["buffer_group"])
# Out:
# (48, 28, 24)

# %%
data_path + "beta_test_20150826_buffer_" + i + ".json"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-6c03fee63650> in <module>()
# ----> 1 data_path + "beta_test_20150826_buffer_" + i + ".json"
#
# TypeError: cannot concatenate 'str' and 'tuple' objects

# %%
"beta_test_20150826_nobuffer_%d.json" % i
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-142d660cd132> in <module>()
# ----> 1 "beta_test_20150826_nobuffer_%d.json" % i
#
# TypeError: %d format: a number is required, not str

# %%
i
# Out:
# ('fit_group',
#  {0: [17,
#    5,
#    46,
#    38,
#    40,
#    74,
#    63,
#    79,
#    52,
#    68,
#    60,
#    13,
#    34,
#    0,
#    78,
#    71,
#    83,
#    4,
#    96,
#    32,
#    6,
#    58,
#    64,
#    82,
#    99,
#    39,
#    7,
#    26,
#    72,
#    66,
#    49,
#    30,
#    10,
#    33,
#    24,
#    41,
#    28,
#    36,
#    69,
#    25,
#    42,
#    22,
#    43,
#    16,
#    81,
#    80,
#    8,
#    35],
#   1: [85,
#    75,
#    89,
#    48,
#    44,
#    3,
#    20,
#    61,
#    90,
#    62,
#    65,
#    77,
#    88,
#    57,
#    92,
#    31,
#    9,
#    55,
#    93,
#    37,
#    59,
#    94,
#    21,
#    98,
#    70,
#    29,
#    97,
#    15]})
