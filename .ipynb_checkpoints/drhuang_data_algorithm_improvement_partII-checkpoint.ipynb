# %%
import os

import scipy as sp
import numpy as np
import pandas as pd
import sklearn as sk
import networkx as nx

from matplotlib import pyplot as plt
from learning_dist_metrics import ldm

# %matplotlib inline

# %%
user_df = pd.read_csv("data/drhuang_person.csv", header=0)
friend_df = pd.read_csv("data/drhuang_friend.csv", header=0,)

## split data by column
uid_df = user_df["ID"]
profile_df = user_df[[c for c in user_df.columns if c != "ID"]]

# %%
friend_df.head(3)
#friend_df.columns = [""range(0, friend_df.shape[1]-1)
relation_mtx = friend_df.ix[:, 1:]
relation_mtx.head(4)

friend_pairs = []
uid_row = friend_df.ix[:, 0]
uid_col = uid_row

# convert relationship matrix into a list of user pairs
# to represent friendships, iterating through items
# on the lower triangle of the matrix
for i, uid_a in enumerate(uid_row):
    for j, uid_b in enumerate(uid_col):

        if uid_a < uid_b:
            ind = relation_mtx.ix[i, j]
            if ind == 1:
                friend_pairs.append((uid_a, uid_b))

# load relationship into networkx.Graph()
from networkx import Graph

fnx = Graph()
fnx.add_edges_from(friend_pairs)

# %%
def scalar(x):
    _min, _max = min(x), max(x)
    _range = (_max - _min) * 1.0
    res = [(i - _min) / _range for i in x]
    return res

## transform data
new_profile_df = pd.DataFrame()

new_profile_df["ID"]        = uid_df #uid_df["ID"]
new_profile_df["Gender"]    = profile_df.ix[:, 0]
new_profile_df["Age"]       = scalar(profile_df["Age"])
new_profile_df["Region"]    = scalar(profile_df["Region"])
new_profile_df["Education"] = scalar(profile_df["Education"])
new_profile_df["Income"]    = scalar(profile_df["Income"])
new_profile_df["Hobby"]     = scalar(profile_df["Hobby"])
new_profile_df["Duration"]  = scalar(profile_df["Duration"])

# %%
import scipy as sp
import numpy as np
import pandas as pd

from scipy.stats import rayleigh
from scipy.stats import ks_2samp
from numpy import linspace
from numpy.random import choice
from networkx import Graph
from learning_dist_metrics.ldm import LDM
from learning_dist_metrics.dist_metrics import weighted_euclidean


def user_grouped_dist(user_id, weights, profile_df, friends_networkx):
    """ Calculate distances between a user and whose friends
        and distance between a user and whose non-friends.
        The groupped distance vector will be output.

    Parameters:
    ----------
    * user_id: {integer}, the target user's ID
    * weights: {vector-like, float}, the vector of feature weights which
        is extracted by LDM().fit(x, y).get_transform_matrix()
    * profile_df: {matrix-like, pandas.DataFrame}, user profile dataframe
        with columns: ["ID", "x0" - "xn"]
    * friends_networkx: {networkx.Graph()}, Graph() object from Networkx
        to store the relationships informat
    Returns:
    -------
    res: {list, list of integers}, a list of two lists, which store the distances
        of either friends and non-friends separately.

    Examples:
    ---------
    weights = ldm().fit(df, friends_list).get_transform_matrix()
    profile_df = users_df[ ["ID"] + cols ]
    user_dist = user_grouped_dist(user_id = 0, weights = weights
        , profile_df, friends_df)
    print user_dist["friends"]
    print user_dist["nonfriends"]
    """
    cols = [col for col in profile_df.columns if col is not "ID"]
    # get the user profile information of the target users
    user_profile = profile_df.ix[profile_df.ID == user_id, cols].as_matrix()
    # get the user_id of friends of the target user
    friends_ls = friends_networkx.neighbors(user_id)
    all_ids = profile_df.ID
    non_friends_ls = [u for u in all_ids if u not in friends_ls + [user_id]]

    sim_dist_vec = []
    for f_id in friends_ls:
        friend_profile = profile_df.ix[profile_df.ID == f_id, cols].as_matrix()
        the_dist = weighted_euclidean(user_profile, friend_profile, weights)
        sim_dist_vec.append(the_dist)

    diff_dist_vec = []
    for nf_id in non_friends_ls:
        nonfriend_profile = profile_df.ix[profile_df.ID == nf_id, cols].as_matrix()
        the_dist = weighted_euclidean(user_profile, nonfriend_profile, weights)
        diff_dist_vec.append(the_dist)

    res = [sim_dist_vec, diff_dist_vec]
    return res


def user_dist_kstest(sim_dist_vec, diff_dist_vec,
                     fit_rayleigh=False, _n=100):
						 
    """ Test the goodness of a given weights to defferentiate friend distance
        distributions and non-friend distance distributions of a given user.
        The distance distribution is considered to follow Rayleigh distribution.

    Parameters:
    ----------
    sim_dist_vec: {vector-like (list), float}, distances between friends
                  and the user
    diff_dist_vec: {vector-like (list), float}, distances between non-fri
                   -ends and the user
    fit_rayleigh: {boolean}, determine if fit data into Rayleigth distri
                  -bution
    _n: {integer}, number of random samples generated from estimated
        distribution

    Returns:
    -------
    * res: {float}: p-value of ks-test with assumption that distances follow
            Rayleigh distribution.

    Examples:
    ---------
    pval = user_dist_kstest(sim_dist_vec, diff_dist_vec)
    """
    # is_valid = (len(sim_dist_vec) >= min_nobs) & \
    #           (len(diff_dist_vec) >= min_nobs) # not used yet
    if fit_rayleigh:
        friend_param = rayleigh.fit(sim_dist_vec)
        nonfriend_param = rayleigh.fit(diff_dist_vec)

        samp_friend = rayleigh.rvs(friend_param[0], friend_param[1], _n)
        samp_nonfriend = rayleigh.rvs(nonfriend_param[0], nonfriend_param[1], _n)

        # ouput p-value of ks-test
        res = ks_2samp(samp_friend, samp_nonfriend)[1]
    else:
        res = ks_2samp(sim_dist_vec, diff_dist_vec)[1]
		
    return res


def users_filter_by_weights(weights, profile_df, friends_networkx,
                            pval_threshold=0.5,
                            mutate_rate=0.4,
                            min_friend_cnt=10,
                            users_list=None,
                            fit_rayleigh=False,
                            _n=1000,
                            is_debug=False):
    """ Split users into two groups, "keep" and "mutate", with respect to
        p-value of the ks-test on the null hypothesis that the distribution of
        friends' weighted distance is not significantly different from the
        couterpart for non-friends. Assume the weighted distances of each group
        follow Rayleigh distribution.

    Parameters:
    ----------
    weights: {vector-like, float}, the vector of feature weights which
        is extracted by LDM().fit(x, y).get_transform_matrix()
    users_list: {vector-like, integer}, the list of user id
    profile_df: {matrix-like, pandas.DataFrame}, user profile dataframe
        with columns: ["ID", "x0" - "xn"]
    friends_networkx: {networkx.Graph()}, Graph() object from Networkx to store
        the relationships information
    pval_threshold: {float}, the threshold for p-value to reject hypothesis
    min_friend_cnt: {integer}, drop users whose total of friends is less than
       this minimum count
    mutate_rate: {float}, a float value [0 - 1] determine the percentage of
       bad_fits member sent to mutation
    fit_rayleigh: {boolean}, determine if fit data into Rayleigth distri
                  -bution
    _n: {integer}, number of random samples generated from estimated
        distribution
    is_debug: {boolean}, to control if it yeilds by-product information

    Returns:
    -------
    res: {list} grouped list of user ids
        res[0] stores all users whose null hypothesis does not holds;
        res[1] stores all users whose null hypothesis hold null hypothesis,
        given weights, distance distribution of all friends is significantly
        different from distance distribution of all non-friends

    Examples:
    --------
    weights = ldm().fit(df, friends_list).get_transform_matrix()
    profile_df = users_df[["ID"] + cols]
    grouped_users = users_filter_by_weights(weights,
                       profile_df, friends_df, pval_threshold = 0.10,
                       min_friend_cnt = 10)

    Notes:
    -----
    min_friend_cnt is not implemented
    """
    # all_users_ids = list(set(profile_df.ID))
    # users_list
    # container for users meeting different critiria
    pvals = []
    if users_list is None:
        users_list = list(profile_df.ix[:, 0])

    for uid in users_list:
        res_dists = user_grouped_dist(uid, weights, profile_df, friends_networkx)
        pval = user_dist_kstest(res_dists[0], res_dists[1], fit_rayleigh, _n)
        pvals.append(pval)

    sorted_id_pval = sorted(zip(users_list, pvals), key=lambda x: x[1])
    
    if is_debug:
        good_fits = [i for i, p in sorted_id_pval if p < pval_threshold]
        bad_fits = [i for i, p in sorted_id_pval if p >= pval_threshold]
        good_pvals = [p for i, p in sorted_id_pval if p < pval_threshold]
        bad_pvals = [i for i, p in sorted_id_pval if p >= pval_threshold]
    else:
        good_fits = [i for i, p in sorted_id_pval if p < pval_threshold]
        bad_fits = [i for i, p in sorted_id_pval if p >= pval_threshold]

    if len(bad_fits) > 0:
        mutate_size = np.ceil(len(bad_fits) * mutate_rate)
        mutate_size = max(int(mutate_size), 1)
        id_retain = good_fits + bad_fits[mutate_size:]
        id_mutate = bad_fits[:mutate_size]

        if len(good_pvals) > 0 or len(bad_pvals) > 0:
            pvals_retain = good_pvals + bad_pvals[mutate_size:]
            pvals_mutate = bad_pvals[mutate_size:]
    else:
        id_retain = good_fits
        id_mutate = bad_fits

    if is_debug is True:
        res = [id_retain, id_mutate, pvals_retain, pvals_mutate]
    else:
        res = [id_retain, id_mutate]
        
    return res


def ldm_train_with_list(users_list, profile_df, friends, retain_type=1):
    """ learning distance matrics with ldm() instance, provided with selected
        list of users.

    Parameters:
    -----------
    users_list: {vector-like, integer}, the list of user id
    profile_df: {matrix-like, pandas.DataFrame}, user profile dataframe
        with columns: ["ID", "x0" - "xn"]
    friends: {list of tuple}, each tuple keeps a pair of user id
    retain_type: {integer}, 0, adopting 'or' logic by keeping relationship in
        friends_df if either of entities is in user_list 1, adopting 'and'
        logic

    Returns:
    -------
    res: {vector-like, float}, output of ldm.get_transform_matrix()

    Examples:
    ---------
    new_dist_metrics = ldm_train_with_list(user_list, profile_df, friends_df)
    """
    if retain_type == 0:
        friends = [(a, b) for a, b in friends if \
            a in users_list or b in users_list]
    else:
        friends = [(a, b) for a, b in friends if \
            a in users_list and b in users_list]
    
    ldm = LDM()    
    ldm.fit(profile_df, friends)
    weight_vec = ldm.get_transform_matrix()
    return weight_vec     


def hyper_parameter_tester(weights_a, weights_b, fit_rayleigh, num):
    
    """
    """
    
    num_friends = []
    num_nonfriends = []
    ks_pvals_right = []
    ks_pvals_wrong = []

    for uid in tg0_ids: 
        # Compare the distribution of a user's distances of all of his/her friends
        # against the distribuiton of a users's distances of all of his/her non-friends,
        # The collection of non-friends may include those users of two categories with
        # respect to their relationships to the target user: 
        # a. the users who are not likened by the target users 
        # b. the users who are likely to be befriended by the users however
        #    the users do not have a change to be exposed to her/him.
        sim_dists, diff_dists = user_grouped_dist(uid, weights_a, profile_df, fnx)
        pval = user_dist_kstest(sim_dists, diff_dists, fit_rayleigh=fit_rayleigh, _n = num)
        ks_pvals_right.append(pval)
    
        sim_dists, diff_dists = user_grouped_dist(uid, weights_b, profile_df, fnx)
        pval = user_dist_kstest(sim_dists, diff_dists, fit_rayleigh=fit_rayleigh, _n = num)
        ks_pvals_wrong.append(pval)
    
        num_friends.append(len(sim_dists))
        num_nonfriends.append(len(diff_dists))
    
    res_report = pd.DataFrame({"ID": tg0_ids, 
		                       "num_friends": num_friends, 
                               "num_nonfriends": num_nonfriends, 
                               "true_pval": ks_pvals_right,
                               "wrong_pval": ks_pvals_wrong})
							   
    return res_report

# %%
all_uids = user_df["ID"].unique()

w = ldm_train_with_list(all_uids, new_profile_df, friend_pairs, retain_type=1)
# Out:
# --- 26.0992388725 seconds ---

# %%
import cProfile, pstats, StringIO

pr = cProfile.Profile()
pr.enable()
print "Profiler start analyzing ... "

ldm = LDM()
ldm.fit(new_profile_df, friend_pairs)

pr.disable()
print "Profiler stop here ... "
# Out:
# --- 32.6142828465 seconds ---

# %%
s = StringIO.StringIO()
sortby = 'cumulative'
ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
ps.print_stats()
print s.getvalue()
# Out:
#          34811825 function calls (34811821 primitive calls) in 33.963 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.000    0.000   33.963   11.321 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:3005(run_code)
#         1    0.000    0.000   33.963   33.963 <ipython-input-67-f6fe47afd699>:7(<module>)
#         1    0.000    0.000   33.963   33.963 learning_dist_metrics/ldm.py:48(fit)
#         1    0.003    0.003   33.963   33.963 learning_dist_metrics/ldm.py:88(_fit)
#       185    0.002    0.000   32.790    0.177 learning_dist_metrics/ldm.py:134(objective_func)
#       370    0.532    0.001   32.768    0.089 learning_dist_metrics/dist_metrics.py:62(all_pairwise_dist)
#         1    0.000    0.000   32.614   32.614 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/optimize/_minimize.py:37(minimize)
#         1    0.001    0.001   32.614   32.614 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/optimize/lbfgsb.py:199(_minimize_lbfgsb)
#        23    0.000    0.000   32.614    1.418 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/optimize/lbfgsb.py:260(func_and_grad)
#       184    0.000    0.000   32.612    0.177 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.py:280(function_wrapper)
#    915750    1.400    0.000   32.166    0.000 learning_dist_metrics/dist_metrics.py:29(pairwise_dist_wrapper)
#    915750   11.167    0.000   30.484    0.000 learning_dist_metrics/dist_metrics.py:13(weighted_euclidean)
#        23    0.001    0.000   28.522    1.240 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.py:544(_approx_fprime_helper)
#       185    0.002    0.000   22.867    0.124 learning_dist_metrics/dist_metrics.py:88(sum_grouped_dist)
#    915750    1.304    0.000   16.341    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/spatial/distance.py:199(euclidean)
#       185    0.013    0.000    9.921    0.054 learning_dist_metrics/dist_metrics.py:110(squared_sum_grouped_dist)
#   1831500    1.717    0.000    8.816    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/spatial/distance.py:119(_validate_vector)
#    915750    1.660    0.000    6.221    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/linalg/misc.py:12(norm)
#    915750    1.392    0.000    4.249    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.py:550(asarray_chkfinite)
#   1831500    1.890    0.000    3.809    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/shape_base.py:8(atleast_1d)
#   2747251    0.962    0.000    3.748    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/numeric.py:394(asarray)
#   4578755    3.610    0.000    3.610    0.000 {numpy.core.multiarray.array}
#   1831500    2.869    0.000    2.869    0.000 {zip}
#    915751    0.295    0.000    2.208    0.000 {method 'all' of 'numpy.ndarray' objects}
#    915751    0.251    0.000    1.913    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:40(_all)
#    915752    1.662    0.000    1.662    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#   1831501    0.686    0.000    1.510    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/numeric.py:464(asanyarray)
#         1    1.037    1.037    1.107    1.107 learning_dist_metrics/ldm.py:215(get_exclusive_pairs)
# 5494594/5494590    0.348    0.000    0.348    0.000 {len}
#    915754    0.282    0.000    0.282    0.000 {isinstance}
#   2747252    0.239    0.000    0.239    0.000 {method 'append' of 'list' objects}
#    915750    0.194    0.000    0.194    0.000 {getattr}
#   1831500    0.191    0.000    0.191    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#    915752    0.117    0.000    0.117    0.000 {method 'get' of 'dict' objects}
#      1494    0.070    0.000    0.070    0.000 {method 'remove' of 'list' objects}
#      9900    0.059    0.000    0.059    0.000 learning_dist_metrics/ldm.py:259(find_index)
#       371    0.005    0.000    0.005    0.000 {sum}
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:2199(as_matrix)
#         3    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/codeop.py:132(__call__)
#         3    0.000    0.000    0.000    0.000 {compile}
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2701(as_matrix)
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2715(_interleave)
#        58    0.000    0.000    0.000    0.000 {numpy.core.multiarray.zeros}
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:1772(any)
#         2    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/iostream.py:207(write)
#        24    0.000    0.000    0.000    0.000 {range}
#        40    0.000    0.000    0.000    0.000 {method 'tostring' of 'numpy.ndarray' objects}
#        56    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:3744(_interleaved_dtype)
#         1    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:37(_any)
#         1    0.000    0.000    0.000    0.000 learning_dist_metrics/ldm.py:250(vec_normalized)
#         2    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2204(shape)
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:2130(_consolidate_inplace)
#         3    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:1107(user_global_ns)
#         1    0.000    0.000    0.000    0.000 <ipython-input-67-f6fe47afd699>:6(<module>)
#         2    0.000    0.000    0.000    0.000 {method 'decode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 learning_dist_metrics/ldm.py:41(__init__)
#         6    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2206(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:2122(_protect_consolidate)
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/getlimits.py:93(__new__)
#         2    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/encodings/utf_8.py:15(decode)
#         2    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/iostream.py:102(_check_mp_mode)
#         2    0.000    0.000    0.000    0.000 {_codecs.utf_8_decode}
#         7    0.000    0.000    0.000    0.000 {round}
#         3    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/core/hooks.py:127(__call__)
#         3    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/utils/ipstruct.py:125(__getattr__)
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:3752(_lcd_dtype)
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2573(is_mixed_type)
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:2131(<lambda>)
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:2085(__setattr__)
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         4    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/index.py:243(__len__)
#         2    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/iostream.py:93(_is_master_process)
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2821(consolidate)
#         1    0.000    0.000    0.000    0.000 {numpy.core.multiarray.empty}
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2246(_is_single_block)
#         4    0.000    0.000    0.000    0.000 {time.time}
#         2    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2560(is_consolidated)
#         9    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:3748(<lambda>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-67-f6fe47afd699>:9(<module>)
#         2    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {callable}
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:228(dtype)
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2836(_consolidate_inplace)
#         2    0.000    0.000    0.000    0.000 {posix.getpid}
#         1    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:2208(ndim)
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.py:275(wrap_function)
#         1    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:119(mgr_locs)
#         3    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/IPython/core/hooks.py:192(pre_run_code_hook)
#         1    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.py:127(_check_unknown_options)
#         2    0.000    0.000    0.000    0.000 /home/beingzy/anaconda/lib/python2.7/site-packages/pandas/core/internals.py:874(get_values)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# ### Algorithm Optimization
#
# * collect pvalue of each iteration
# * collect the group assign
# * start with 2 container strategy

# %%
# {"id": {"group": [0, 0, 0, 1], "pval": [0.2, 0.1, 0.3, 0.8]}}
user_pvals = {}
user

# %%
# summary of characteristics 
# 1. learning 

# input variables:
profile_df = new_profile_df
friends_networkx = fnx
friends_df = friend_pairs
users_list = all_uids

# learning parameter
RETAIN_TYPE = 0
PVAL = 0.2
MIN_FRIENDS = 10 # not implemented in function
# hyper-parameter
max_iters = 30
mutate_rate = 1
# process controller
counter = 0

# performance collector
num_good_fits = []
num_bad_fits = []
g0_dist_weights = []
g1_dist_weights = []
g0_size = []
g1_size = []

# -------- Initial Weights Leanring ----------- #
ldm = LDM()
ldm.fit(profile_df, friends_df)
the_dist_weights = ldm.get_transform_matrix()

g0, g1 = users_filter_by_weights(weights=the_dist_weights, 
                                 profile_df=profile_df, 
                                 friends_networkx=friends_networkx, 
                                 pval_threshold=PVAL, 
                                 mutate_rate=0.5, 
                                 min_friend_cnt=10, 
                                 users_list=users_list, is_debug=True)
print "# of memebers in group 0: %d, # of memebers in group 1: %d" % (len(g0), len(g1))

# -------- Individual Group Learning ----------- #
while counter < max_iters:
    counter += 1
    #mutate_rate = min(mutate_rate + 0.05, 1)
    print "------- %d iteration --------" % counter
    g0_dist = ldm_train_with_list(g0, profile_df, friends_df, retain_type=RETAIN_TYPE)
    g1_dist = ldm_train_with_list(g1, profile_df, friends_df, retain_type=RETAIN_TYPE)
    print "Group 0's learned distance metrics:"
    print g0_dist
    print "Group 1's learned distance metrics:"
    print g1_dist

    print "---------------------------------------------- "
    g0_good, g0_bad = users_filter_by_weights(weights=g0_dist, 
                                              profile_df=profile_df, 
                                              friends_networkx=friends_networkx, 
                                              pval_threshold=PVAL, 
                                              mutate_rate=0.2, 
                                              min_friend_cnt=10, 
                                              users_list=g0, 
                                              fit_rayleigh=True, 
                                              _n=5000)
    
    print "# of good fits: %d, # of bad fits: %d" % (len(g0_good), len(g0_bad))
    g1_good, g1_bad = users_filter_by_weights(weights=g1_dist, 
                                              profile_df=profile_df, 
                                              friends_networkx=friends_networkx, 
                                              pval_threshold=PVAL, mutate_rate=0.2, min_friend_cnt=10, 
                                              users_list=g1, fit_rayleigh=True, _n=5000)
    print "# of good fits: %d, # of bad fits: %d" % (len(g1_good), len(g1_bad))

    print "---------------------------------------------- "
    g0 = g0_good + g1_bad
    g1 = g0_bad + g1_good
    print "# of memebers in group 0: %d, # of memebers in group 1: %d" % (len(g0), len(g1)) 
    print "*********************************************** \n"
    
    g0_dist_weights.append(g0_dist)
    g1_dist_weights.append(g1_dist)
    num_good_fits.append(len(g0_good) + len(g1_good))
    num_bad_fits.append(len(g0_bad) + len(g1_bad))
    g0_size.append(len(g0))
    g1_size.append(len(g1))
# Out:
# --- 26.7541029453 seconds ---
# # of memebers in group 0: 50, # of memebers in group 1: 50
# ------- 1 iteration --------
# --- 32.3174660206 seconds ---
# --- 24.8918268681 seconds ---
# Group 0's learned distance metrics:
# [0.0, 0.12, 0.0, 0.4, 0.0, 0.47, 0.0]
# Group 1's learned distance metrics:
# [0.0, 0.23, 0.0, 0.29, 0.0, 0.48, 0.0]
# ----------------------------------------------
# # of good fits: 41, # of bad fits: 9
# # of good fits: 42, # of bad fits: 8
# ----------------------------------------------
# # of memebers in group 0: 49, # of memebers in group 1: 51
# ***********************************************
#
# ------- 2 iteration --------
# --- 21.1455001831 seconds ---
# --- 23.3599710464 seconds ---
# Group 0's learned distance metrics:
# [0.0, 0.14, 0.0, 0.33, 0.0, 0.53, 0.0]
# Group 1's learned distance metrics:
# [0.0, 0.2, 0.0, 0.34, 0.0, 0.46, 0.0]
# ----------------------------------------------
# # of good fits: 40, # of bad fits: 9
# # of good fits: 43, # of bad fits: 8
# ----------------------------------------------
# # of memebers in group 0: 48, # of memebers in group 1: 52
# ***********************************************
#
# ------- 3 iteration --------
# --- 34.0803251266 seconds ---
# --- 32.816026926 seconds ---
# Group 0's learned distance metrics:
# [0.0, 0.19, 0.0, 0.33, 0.0, 0.48, 0.0]
# Group 1's learned distance metrics:
# [0.0, 0.1, 0.0, 0.36, 0.0, 0.54, 0.0]
# ----------------------------------------------
# # of good fits: 40, # of bad fits: 8
# # of good fits: 42, # of bad fits: 10
# ----------------------------------------------
# # of memebers in group 0: 50, # of memebers in group 1: 50
# ***********************************************
#
# ------- 4 iteration --------
# --- 22.3457419872 seconds ---
# --- 92.0562531948 seconds ---
# Group 0's learned distance metrics:
# [0.0, 0.17, 0.0, 0.31, 0.0, 0.52, 0.0]
# Group 1's learned distance metrics:
# [0.0, 0.13, 0.0, 0.33, 0.0, 0.54, 0.0]
# ----------------------------------------------
# # of good fits: 43, # of bad fits: 7
# # of good fits: 42, # of bad fits: 8
# ----------------------------------------------
# # of memebers in group 0: 51, # of memebers in group 1: 49
# ***********************************************
#
# ------- 5 iteration --------
# --- 21.3131089211 seconds ---
# --- 90.7698469162 seconds ---
# Group 0's learned distance metrics:
# [0.0, 0.18, 0.0, 0.3, 0.0, 0.52, 0.0]
# Group 1's learned distance metrics:
# [0.0, 0.12, 0.0, 0.4, 0.0, 0.48, 0.0]
# ----------------------------------------------
# # of good fits: 42, # of bad fits: 9
# # of good fits: 42, # of bad fits: 7
# ----------------------------------------------
# # of memebers in group 0: 49, # of memebers in group 1: 51
# ***********************************************
#
# ------- 6 iteration --------
# --- 19.5649430752 seconds ---
# --- 28.9990611076 seconds ---
# Group 0's learned distance metrics:
# [0.0, 0.17, 0.0, 0.3, 0.0, 0.52, 0.0]
# Group 1's learned distance metrics:
# [0.0, 0.1, 0.0, 0.41, 0.0, 0.49, 0.0]
# ----------------------------------------------
# # of good fits: 41, # of bad fits: 8
# # of good fits: 41, # of bad fits: 10
# ----------------------------------------------
# # of memebers in group 0: 51, # of memebers in group 1: 49
# ***********************************************
#
# ------- 7 iteration --------
# --- 34.9696218967 seconds ---
# --- 25.8931388855 seconds ---
# Group 0's learned distance metrics:
# [0.0, 0.18, 0.0, 0.32, 0.0, 0.5, 0.0]
# Group 1's learned distance metrics:
# [0.0, 0.12, 0.0, 0.42, 0.0, 0.47, 0.0]
# ----------------------------------------------
# # of good fits: 43, # of bad fits: 8
# # of good fits: 40, # of bad fits: 9
# ----------------------------------------------
# # of memebers in group 0: 52, # of memebers in group 1: 48
# ***********************************************
#
# ------- 8 iteration --------
# --- 24.6510360241 seconds ---
# --- 23.8187379837 seconds ---
# Group 0's learned distance metrics:
# [0.0, 0.18, 0.0, 0.27, 0.0, 0.55, 0.0]
# Group 1's learned distance metrics:
# [0.0, 0.09, 0.0, 0.42, 0.0, 0.48, 0.0]
# ----------------------------------------------
# # of good fits: 43, # of bad fits: 9
# # of good fits: 39, # of bad fits: 9
# ----------------------------------------------
# # of memebers in group 0: 52, # of memebers in group 1: 48
# ***********************************************
#
# ------- 9 iteration --------
# --- 21.5969500542 seconds ---
# --- 23.3719620705 seconds ---
# Group 0's learned distance metrics:
# [0.0, 0.16, 0.0, 0.29, 0.0, 0.56, 0.0]
# Group 1's learned distance metrics:
# [0.0, 0.11, 0.0, 0.36, 0.0, 0.52, 0.0]
# ----------------------------------------------
# # of good fits: 45, # of bad fits: 7
# # of good fits: 40, # of bad fits: 8
# ----------------------------------------------
# # of memebers in group 0: 53, # of memebers in group 1: 47
# ***********************************************
#
# ------- 10 iteration --------
# --- 22.6066398621 seconds ---
# --- 26.0726110935 seconds ---
# Group 0's learned distance metrics:
# [0.0, 0.16, 0.0, 0.3, 0.0, 0.54, 0.0]
# Group 1's learned distance metrics:
# [0.0, 0.17, 0.0, 0.35, 0.0, 0.49, 0.0]
# ----------------------------------------------
# # of good fits: 44, # of bad fits: 9
# # of good fits: 39, # of bad fits: 8
# ----------------------------------------------
# # of memebers in group 0: 52, # of memebers in group 1: 48
# ***********************************************
#
# ------- 11 iteration --------
# --- 21.2253570557 seconds ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-1ba57a62f738> in <module>()
#      43     print "------- %d iteration --------" % counter
#      44     g0_dist = ldm_train_with_list(g0, profile_df, friends_df, retain_type=RETAIN_TYPE)
# ---> 45     g1_dist = ldm_train_with_list(g1, profile_df, friends_df, retain_type=RETAIN_TYPE)
#      46     print "Group 0's learned distance metrics:"
#      47     print g0_dist
#
# <ipython-input-9-c58932d6ff09> in ldm_train_with_list(users_list, profile_df, friends, retain_type)
#     222
#     223     ldm = LDM()
# --> 224     ldm.fit(profile_df, friends)
#     225     weight_vec = ldm.get_transform_matrix()
#     226     return weight_vec
#
# /home/beingzy/Documents/projects/phd_experiment/learning_dist_metrics/ldm.pyc in fit(self, X, S, D)
#      65         _ratio: float
#      66     """
# ---> 67         self._fit(X, S, D)
#      68         return self
#      69
#
# /home/beingzy/Documents/projects/phd_experiment/learning_dist_metrics/ldm.pyc in _fit(self, X, S, D)
#     148         if self._is_debug:
#     149             try:
# --> 150                 print "Examples of S: %s" % S[:5], len(S)
#     151                 print "Examples of D: %s" % D[:5], len(D)
#     152                 print "Examples of X: %s" % X[:5, :], X.shape
#
# /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/optimize/_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     425     elif meth == 'l-bfgs-b':
#     426         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 427                                 callback=callback, **options)
#     428     elif meth == 'tnc':
#     429         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/optimize/lbfgsb.pyc in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, **unknown_options)
#     313                 # minimization routine wants f and g at the current x
#     314                 # Overwrite f and g:
# --> 315                 f, g = func_and_grad(x)
#     316         elif task_str.startswith(b'NEW_X'):
#     317             # new iteration
#
# /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/optimize/lbfgsb.pyc in func_and_grad(x)
#     260         def func_and_grad(x):
#     261             f = fun(x, *args)
# --> 262             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     263             return f, g
#     264     else:
#
# /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in _approx_fprime_helper(xk, f, epsilon, args, f0)
#     554         ei[k] = 1.0
#     555         d = epsilon * ei
# --> 556         grad[k] = (f(*((xk + d,) + args)) - f0) / d[k]
#     557         ei[k] = 0.0
#     558     return grad
#
# /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     280     def function_wrapper(*wrapper_args):
#     281         ncalls[0] += 1
# --> 282         return function(*(wrapper_args + args))
#     283
#     284     return ncalls, function_wrapper
#
# /home/beingzy/Documents/projects/phd_experiment/learning_dist_metrics/ldm.pyc in objective_func(w)
#     133             keep_items = [find_index(i, ids) for i in ids \
#     134                 if i in covered_items]
# --> 135             X = X.ix[keep_items, :]
#     136
#     137         # Convert ids in D and S into row index, in order to provide them to
#
# /home/beingzy/Documents/projects/phd_experiment/learning_dist_metrics/dist_metrics.pyc in squared_sum_grouped_dist(pair_list, data, weights)
#     127         sum_dist = squared_sum_grouped_dist(p, data)
#     128     """
# --> 129     dist = all_pairwise_dist(pair_list, data, weights)
#     130     dist_squared = [d * d for d in dist]
#     131     return sum(dist_squared)
#
# /home/beingzy/Documents/projects/phd_experiment/learning_dist_metrics/dist_metrics.pyc in all_pairwise_dist(pair_list, data, weights)
#      82     dist = []
#      83     for i in pair_list:
# ---> 84         dist.append(pairwise_dist_wrapper(i, data, weights))
#      85     return dist
#      86
#
# /home/beingzy/Documents/projects/phd_experiment/learning_dist_metrics/dist_metrics.pyc in pairwise_dist_wrapper(pair, data, weights)
#      57     a = data[pair[0], :]
#      58     b = data[pair[1], :]
# ---> 59     return weighted_euclidean(a, b, weights)
#      60
#      61
#
# /home/beingzy/Documents/projects/phd_experiment/learning_dist_metrics/dist_metrics.pyc in weighted_euclidean(x, y, w)
#      24     x = [sqrt(i_w) * i_x for i_w, i_x in zip(w, x)]
#      25     y = [sqrt(i_w) * i_y for i_w, i_y in zip(w, y)]
# ---> 26     return euclidean(x, y)
#      27
#      28
#
# /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/spatial/distance.pyc in euclidean(u, v)
#     221     """
#     222     u = _validate_vector(u)
# --> 223     v = _validate_vector(v)
#     224     dist = norm(u - v)
#     225     return dist
#
# /home/beingzy/anaconda/lib/python2.7/site-packages/scipy/spatial/distance.pyc in _validate_vector(u, dtype)
#     119 def _validate_vector(u, dtype=None):
#     120     # XXX Is order='c' really necessary?
# --> 121     u = np.asarray(u, dtype=dtype, order='c').squeeze()
#     122     # Ensure values such as u=1 and u=[1] still return 1-D arrays.
#     123     u = np.atleast_1d(u)
#
# /home/beingzy/anaconda/lib/python2.7/site-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     460
#     461     """
# --> 462     return array(a, dtype, copy=False, order=order)
#     463
#     464 def asanyarray(a, dtype=None, order=None):
#
# KeyboardInterrupt:
